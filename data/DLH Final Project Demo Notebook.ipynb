# %% [markdown]
# # CS598 DL4H Final Project Demo Notebook
# #### by Rui Zou and Yueming Pang, May 2023
#
# In this notebook, we demonstrate the key steps involved in reproducing the research paper titled "GAMENet: Graph Augmented MEmory Networks for Recommending Medication Combination". Our demo covers various stages, including data preprocessing, dataset splitting, and running different base models along with the GAMENet model to obtain results.
#
# #### Data Preprocessing
# To prepare the dataset for our project, we perform several data preprocessing steps such as cleaning, filtering, and feature engineering. We also explore the dataset to understand the distribution of features and print out the statistics of the dataset.
#
# #### Dataset Splitting
# We discuss the dataset splitting method used in the paper and explore its effectiveness in our experiments. We then propose the additional step to make the splitting method more robust. We split the dataset into training, validation, and test sets, and will train the model using training and validation datasets, and compare the performance of the models using the test dataset.
#
# #### Base Models and GAMENet
# We run several base models, including nearest visit, LR and several neural network-based models, to establish a baseline for comparison. We then implement the GAMENet model and compare its performance with the baseline models.

# %% [markdown]
# ## Part 1: Data Preprocessing
# In this part, we process the patient EHR data, including medication, diagnosis, and procedure data, so that they can be fed into the models later. At the end of this section, we print the statistics of the processed data.
#
# We cleaned the original code in the authors' repo, removed redundancies, added functions, and added doc strings and comments.

# %% [markdown]
# ### Load Libraries

# %%
import pandas as pd
import functools
import dill
import numpy as np
from collections import defaultdict
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Read from MIMIC csv files

# %%
# Files can be downloaded from https://mimic.physionet.org/gettingstarted/dbsetup/
med_file = 'PRESCRIPTIONS.csv'
diag_file = 'DIAGNOSES_ICD.csv'
procedure_file = 'PROCEDURES_ICD.csv'

# drug code mapping files (already in ./data/)
ndc2atc_file = 'ndc2atc_level4.csv' 
cid_atc = 'drug-atc.csv'
ndc_rxnorm_file = 'ndc2rxnorm_mapping.txt'

# drug-drug interactions can be down https://www.dropbox.com/s/8os4pd2zmp2jemd/drug-DDI.csv?dl=0
ddi_file = 'drug-DDI.csv'

# %% [markdown]
# ### Preprocessing MIMIC csv files, filter the medication used in the first 24 hours, and print the statistics

# %%
def convert_to_list(x):
    """
    This function takes an input `x` and converts it into a list.
    
    Args:
        x (str or iterable): The input to be converted into a list.
    
    Returns:
        list: The input `x` as a list. If `x` is already a list, it is returned as is.
    """
    if isinstance(x, str):
        return [x]
    else:
        return list(x)

def process_procedure(procedure_file):
    """
    Read and process the procedure CSV file.
    
    Args:
        procedure_file: str, the path to the CSV file containing procedure data
    
    Returns:
        pro_pd: pandas DataFrame, the processed procedure data
    """
    # Read the CSV file and set data types
    pro_pd = pd.read_csv(procedure_file, dtype={'ICD9_CODE':'category'})

    # Drop unnecessary columns and duplicates
    pro_pd = pro_pd.drop(columns=['ROW_ID', 'SEQ_NUM']).drop_duplicates()

    # Sort the data by SUBJECT_ID, HADM_ID, and ICD9_CODE
    pro_pd = pro_pd.sort_values(by=['SUBJECT_ID', 'HADM_ID', 'ICD9_CODE'])

    # Reset the index
    pro_pd = pro_pd.reset_index(drop=True)

    return pro_pd

def process_med(med_file):
    """
    Processes medication data from a CSV file and returns a cleaned and filtered pandas DataFrame.

    Args:
        med_file (str): A string specifying the path and file name of the CSV file containing medication data.

    Returns:
        pandas DataFrame: A cleaned and filtered pandas DataFrame containing medication data.
    """
    med_pd = pd.read_csv(med_file, dtype={'NDC': 'category'})
    
    # filter and clean data
    med_pd.drop(columns=['ROW_ID','DRUG_TYPE','DRUG_NAME_POE','DRUG_NAME_GENERIC',
                          'FORMULARY_DRUG_CD','GSN','PROD_STRENGTH','DOSE_VAL_RX',
                          'DOSE_UNIT_RX','FORM_VAL_DISP','FORM_UNIT_DISP',
                          'ROUTE','ENDDATE','DRUG'], inplace=True)
    med_pd.drop(med_pd[med_pd['NDC'] == '0'].index, axis=0, inplace=True)
    med_pd.fillna(method='pad', inplace=True)
    med_pd.dropna(inplace=True)
    med_pd['ICUSTAY_ID'] = med_pd['ICUSTAY_ID'].astype('int64')
    med_pd['STARTDATE'] = pd.to_datetime(med_pd['STARTDATE'], format='%Y-%m-%d %H:%M:%S')    
    med_pd.drop_duplicates(inplace=True)
    
    # sort by columns
    med_pd.sort_values(by=['SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID', 'STARTDATE'], inplace=True)
    med_pd.reset_index(drop=True, inplace=True)
    
    def filter_first24hour_med(med_pd):
        """
        Filter medication data to keep only the first ICU stay for each patient and merge with original dataframe to keep the NDC code.

        Args:
            med_pd: pandas.DataFrame
                The medication data to be processed.

        Returns:
            pandas.DataFrame
                The processed medication data with only the first ICU stay for each patient and the NDC code.
        """
        # Keep only the first ICU stay for each patient
        med_pd_new = med_pd.drop(columns=['NDC'])
        med_pd_new = med_pd_new.drop_duplicates(subset=['SUBJECT_ID','HADM_ID','ICUSTAY_ID'], keep='first')

        # Merge with original dataframe to keep the NDC code
        med_pd_new = pd.merge(med_pd_new, med_pd, on=['SUBJECT_ID','HADM_ID','ICUSTAY_ID','STARTDATE'])
        med_pd_new = med_pd_new.drop(columns=['STARTDATE'])

        return med_pd_new

    med_pd = filter_first24hour_med(med_pd)

    # Drop the 'ICUSTAY_ID' column from med_pd
    med_pd = med_pd.drop(columns=['ICUSTAY_ID'])

    # Drop duplicates from med_pd
    med_pd = med_pd.drop_duplicates().reset_index(drop=True)
    
    # visit > 2
    def process_visit_lg2(med_pd):
        """
        Filters `med_pd` dataframe to include only the first ICU stay for each patient with more than one visit.
        
        Args:
            med_pd : pandas.DataFrame
                The input DataFrame containing medication data.
            
        Returns:
            pandas.DataFrame
                A new DataFrame with the same columns as `med_pd`, but only including rows for the first ICU stay of each
                patient with more than one visit. If a patient has only one ICU stay, all rows for that patient are included.
                Additionally, a new column 'HADM_ID_Len' is added which contains the number of HADM_IDs per SUBJECT_ID.
        """
        # Get unique HADM_IDs per SUBJECT_ID
        unique_hadm_ids = med_pd[['SUBJECT_ID', 'HADM_ID']].drop_duplicates()
        subject_counts = unique_hadm_ids['SUBJECT_ID'].value_counts()

        # Filter SUBJECT_IDs with visit counts > 1
        subjects_with_multiple_visits = subject_counts[subject_counts > 1].index
        visits_lg2 = unique_hadm_ids[unique_hadm_ids['SUBJECT_ID'].isin(subjects_with_multiple_visits)]

        # Add HADM_ID count as a new column
        visits_lg2['HADM_ID_Len'] = visits_lg2.groupby('SUBJECT_ID')['HADM_ID'].transform('count')

        # Return result
        return visits_lg2

    med_pd_lg2 = process_visit_lg2(med_pd).reset_index(drop=True)    
    med_pd = med_pd.merge(med_pd_lg2[['SUBJECT_ID']], on='SUBJECT_ID', how='inner')    
    
    return med_pd.reset_index(drop=True)

def process_diag(diag_file):
    """
    Reads in the diagnosis data from the provided file, removes any rows with missing data, unnecessary columns,
    and duplicate rows. The resulting DataFrame is sorted by subject ID and hospital admission ID and the index is reset.
    
    Args:
        diag_file: string, path to the diagnosis data file
    
    Returns:
        diag_pd: pandas DataFrame, diagnosis data processed and sorted by subject ID and hospital admission ID
    """
    # Read in the diagnosis data from the provided file
    diag_pd = pd.read_csv(diag_file)
    
    # Drop any rows with missing data
    diag_pd.dropna(inplace=True)
    
    # Remove unnecessary columns
    diag_pd.drop(columns=['SEQ_NUM','ROW_ID'], inplace=True)
    
    # Drop any duplicate rows
    diag_pd.drop_duplicates(inplace=True)
    
    # Sort the data by subject ID and hospital admission ID
    diag_pd.sort_values(by=['SUBJECT_ID','HADM_ID'], inplace=True)
    
    # Reset the index of the DataFrame and return it
    return diag_pd.reset_index(drop=True)

def ndc2atc4(med_pd):
    """
    Converts the NDC codes in the medication DataFrame `med_pd` to ATC4 codes using external data files.

    Args:
        med_pd (pandas DataFrame): DataFrame containing medication data with NDC codes.

    Returns:
        pandas DataFrame: DataFrame containing medication data with ATC4 codes.
    """
    with open(ndc_rxnorm_file, 'r') as f:
        ndc2rxnorm = eval(f.read())
    
    med_pd['RXCUI'] = med_pd['NDC'].map(ndc2rxnorm)
    med_pd.dropna(subset=['RXCUI'], inplace=True)

    rxnorm2atc = pd.read_csv(ndc2atc_file, usecols=['RXCUI', 'ATC4'], squeeze=True)
    rxnorm2atc.drop_duplicates(subset=['RXCUI'], inplace=True)

    med_pd = med_pd[~med_pd['RXCUI'].isin([''])]
    med_pd['RXCUI'] = med_pd['RXCUI'].astype('int64')

    med_pd = med_pd.merge(rxnorm2atc, on=['RXCUI'])
    med_pd.drop(columns=['NDC', 'RXCUI'], inplace=True)

    med_pd['NDC'] = med_pd['ATC4'].str[:4]
    med_pd.drop_duplicates(inplace=True)
    med_pd.reset_index(drop=True, inplace=True)

    return med_pd

def filter_2000_most_diag(diag_pd):
    """
    Filter the diagnosis DataFrame to keep only the rows with the top 2000 most frequent ICD9 codes.
    
    Args:
        diag_pd : pandas.DataFrame
            DataFrame containing diagnosis data with 'ICD9_CODE' column.
    
    Returns:
        pandas.DataFrame
            DataFrame with only the rows containing ICD9 codes in the top 2000 most frequent list.
    """
    # Get the top 2000 most frequent ICD9 codes
    diag_count = diag_pd['ICD9_CODE'].value_counts().reset_index().rename(columns={'index': 'ICD9_CODE', 'ICD9_CODE': 'count'})
    top_2000_icd9_codes = diag_count.loc[:1999, 'ICD9_CODE'].tolist()
    
    # Filter the DataFrame to keep only the rows with ICD9 codes in the top 2000
    diag_pd = diag_pd[diag_pd['ICD9_CODE'].isin(top_2000_icd9_codes)]
    
    return diag_pd.reset_index(drop=True)

def process_all():
    """
    This function processes medication, diagnosis, and procedure data and returns a pandas DataFrame with the processed data.
    
    Returns:
        data (pandas DataFrame): A DataFrame containing processed medication, diagnosis, and procedure data, merged on unique SUBJECT_ID and HADM_ID. The DataFrame has the following columns:
            - SUBJECT_ID: unique identifier for each patient
            - HADM_ID: unique identifier for each hospital admission
            - ICD9_CODE: list of diagnosis codes associated with the admission
            - NDC: list of medication NDC codes associated with the admission
            - PRO_CODE: list of procedure codes associated with the admission
            - NDC_Len: number of unique NDC codes associated with the admission
    """
    # get med and diag (visit>=2)
    medication_pd = process_med(med_file)
    medication_pd = ndc2atc4(medication_pd)

    diagnosis_pd = process_diag(diag_file)
    diagnosis_pd = filter_2000_most_diag(diagnosis_pd)

    procedure_pd = process_procedure(procedure_file)

    medication_pd_key = medication_pd[['SUBJECT_ID', 'HADM_ID']].drop_duplicates()
    diagnosis_pd_key = diagnosis_pd[['SUBJECT_ID', 'HADM_ID']].drop_duplicates()
    procedure_pd_key = procedure_pd[['SUBJECT_ID', 'HADM_ID']].drop_duplicates()

    combined_key = functools.reduce(lambda x, y: pd.merge(x, y, on=['SUBJECT_ID', 'HADM_ID'], how='inner'), 
                                    [medication_pd_key, diagnosis_pd_key, procedure_pd_key])
    
    diagnosis_pd = diagnosis_pd.merge(combined_key, on=['SUBJECT_ID', 'HADM_ID'], how='inner')
    medication_pd = medication_pd.merge(combined_key, on=['SUBJECT_ID', 'HADM_ID'], how='inner')
    procedure_pd = procedure_pd.merge(combined_key, on=['SUBJECT_ID', 'HADM_ID'], how='inner')

    # flatten and merge
    diagnosis_pd = diagnosis_pd.groupby(by=['SUBJECT_ID','HADM_ID'])['ICD9_CODE'].unique().reset_index()  
    medication_pd = medication_pd.groupby(by=['SUBJECT_ID', 'HADM_ID'])['NDC'].unique().reset_index()
    procedure_pd = procedure_pd.groupby(by=['SUBJECT_ID','HADM_ID'])['ICD9_CODE'].unique().reset_index().rename(columns={'ICD9_CODE':'PRO_CODE'})  
    medication_pd['NDC'] = medication_pd['NDC'].map(convert_to_list)
    procedure_pd['PRO_CODE'] = procedure_pd['PRO_CODE'].map(convert_to_list)
    
    data = functools.reduce(lambda x, y: pd.merge(x, y, on=['SUBJECT_ID', 'HADM_ID'], how='inner'), 
                            [diagnosis_pd, medication_pd, procedure_pd])
    
    data['NDC_Len'] = data['NDC'].map(len)
    return data

def statistics():
    """
    This function prints various statistics related to the processed medical data. These statistics include the number of unique patients and clinical events, the number of unique diagnoses, medications, and procedures, and various averages and maxes calculated over patient visits.

        Prints:
        - #patients: number of unique patients
        - #clinical events: total number of clinical events
        - #diagnosis: number of unique diagnosis codes
        - #med: number of unique medication NDC codes
        - #procedure: number of unique procedure codes
        - #avg of diagnoses: average number of diagnoses per clinical event
        - #avg of medicines: average number of medications per clinical event
        - #avg of procedures: average number of procedures per clinical event
        - #avg of vists: average number of visits per patient
        - #max of diagnoses: maximum number of diagnoses associated with a single visit
        - #max of medicines: maximum number of medications associated with a single visit
        - #max of procedures: maximum number of procedures associated with a single visit
        - #max of visit: maximum number of visits associated with a single patient
    """
    print('#patients ', data['SUBJECT_ID'].nunique())
    print('#clinical events ', len(data))
    
    unique_diag = data['ICD9_CODE'].explode().nunique()
    unique_med = data['NDC'].explode().nunique()
    unique_pro = data['PRO_CODE'].explode().nunique()
    
    print('#diagnosis ', unique_diag)
    print('#med ', unique_med)
    print('#procedure', unique_pro)
    
    avg_diag = 0
    avg_med = 0
    avg_pro = 0
    max_diag = 0
    max_med = 0
    max_pro = 0
    cnt = 0
    max_visit = 0
    avg_visit = 0

    for subject_id in data['SUBJECT_ID'].unique():
        item_data = data[data['SUBJECT_ID'] == subject_id]
        x = []
        y = []
        z = []
        visit_cnt = 0
        for index, row in item_data.iterrows():
            visit_cnt += 1
            cnt += 1
            x.extend(list(row['ICD9_CODE']))
            y.extend(list(row['NDC']))
            z.extend(list(row['PRO_CODE']))
        x = set(x)
        y = set(y)
        z = set(z)
        avg_diag += len(x)
        avg_med += len(y)
        avg_pro += len(z)
        avg_visit += visit_cnt
        if len(x) > max_diag:
            max_diag = len(x)
        if len(y) > max_med:
            max_med = len(y) 
        if len(z) > max_pro:
            max_pro = len(z)
        if visit_cnt > max_visit:
            max_visit = visit_cnt
        
    print('#avg of diagnoses ', avg_diag / cnt)
    print('#avg of medicines ', avg_med / cnt)
    print('#avg of procedures ', avg_pro / cnt)
    print('#avg of vists ', avg_visit / len(data['SUBJECT_ID'].unique()))

    print('#max of diagnoses ', max_diag)
    print('#max of medicines ', max_med)
    print('#max of procedures ', max_pro)
    print('#max of visit ', max_visit)
    
    
data = process_all()
statistics()
data.to_pickle('data_final.pkl')
# Out:
# #patients  6350
# #clinical events  15016
# #diagnosis  1958
# #med  145
# #procedure 1426
# #avg of diagnoses  10.514318060735215
# #avg of medicines  8.80420884389984
# #avg of procedures  3.8445657964837507
# #avg of vists  2.3647244094488187
# #max of diagnoses  128
# #max of medicines  55
# #max of procedures  50
# #max of visit  29

# %% [markdown]
# ### Create vocabulary for medical codes and save patient record in pickle form

# %%
class Voc:
    """
    A vocabulary class that maps words to indices and vice versa.
    """
    
    def __init__(self):
        """
        Initialize the vocabulary with empty word-to-index and index-to-word mappings.
        """
        self.idx2word = {}
        self.word2idx = {}

    def add_sentence(self, sentence):
        """
        Add a sentence to the vocabulary.
        
        Args:
            sentence (list): A list of words in the sentence.
        """
        for word in sentence:
            if word not in self.word2idx:
                self.idx2word[len(self.word2idx)] = word
                self.word2idx[word] = len(self.word2idx)
                
def create_str_token_mapping(df):
    """
    Create string to token mappings for diagnosis, medication, and procedure codes.
    
    Args:
        df (pandas.DataFrame): A DataFrame containing the medical records data.
        
    Returns:
        Tuple[Voc, Voc, Voc]: A tuple of three Voc objects, one for each code type.
    """
    diag_voc = Voc()
    med_voc = Voc()
    pro_voc = Voc()
    
    for index, row in df.iterrows():
        diag_voc.add_sentence(row['ICD9_CODE'])
        med_voc.add_sentence(row['NDC'])
        pro_voc.add_sentence(row['PRO_CODE'])
    
    with open('voc_final.pkl', 'wb') as f:
        dill.dump({'diag_voc': diag_voc, 'med_voc': med_voc, 'pro_voc': pro_voc}, f)
        
    return diag_voc, med_voc, pro_voc

def create_patient_record(df, diag_voc, med_voc, pro_voc):
    """
    Create a patient record data structure from the medical records data.
    
    Args:
        df (pandas.DataFrame): A DataFrame containing the medical records data.
        diag_voc (Voc): A Voc object for diagnosis codes.
        med_voc (Voc): A Voc object for medication codes.
        pro_voc (Voc): A Voc object for procedure codes.
        
    Returns:
        list: A list of patient records, where each record is a list of admissions, and each admission is a
        list of three lists of code indices (one for each code type).
    """
    records = [] # (patient, code_kind:3, codes)  code_kind:diag, proc, med
    for subject_id in df['SUBJECT_ID'].unique():
        item_df = df[df['SUBJECT_ID'] == subject_id]
        patient = []
        for index, row in item_df.iterrows():
            admission = []
            admission.append([diag_voc.word2idx[i] for i in row['ICD9_CODE']])
            admission.append([pro_voc.word2idx[i] for i in row['PRO_CODE']])
            admission.append([med_voc.word2idx[i] for i in row['NDC']])
            patient.append(admission)
        records.append(patient) 
    
    with open('records_final.pkl', 'wb') as f:
        dill.dump(records, f)
        
    return records
        
    
path='data_final.pkl'
df = pd.read_pickle(path)
diag_voc, med_voc, pro_voc = create_str_token_mapping(df)
records = create_patient_record(df, diag_voc, med_voc, pro_voc)
print(len(diag_voc.idx2word), len(med_voc.idx2word), len(pro_voc.idx2word))
# Out:
# 1958 145 1426

# %% [markdown]
# ### Construct DDI, EHR Adj and DDI Adj data

# %%
# atc -> cid
ddi_file = 'drug-DDI.csv'
cid_atc = 'drug-atc.csv'
voc_file = 'voc_final.pkl'
data_path = 'records_final.pkl'
TOPK = 40 # topk drug-drug interaction

records =  dill.load(open(data_path, 'rb'))
cid2atc_dic = defaultdict(set)
med_voc = dill.load(open(voc_file, 'rb'))['med_voc']
med_voc_size = len(med_voc.idx2word)
med_unique_word = [med_voc.idx2word[i] for i in range(med_voc_size)]
atc3_atc4_dic = defaultdict(set)

for item in med_unique_word:
    atc3_atc4_dic[item[:4]].add(item)
    
with open(cid_atc, 'r') as f:
    for line in f:
        line_ls = line[:-1].split(',')
        cid = line_ls[0]
        atcs = line_ls[1:]
        for atc in atcs:
            if len(atc3_atc4_dic[atc[:4]]) != 0:
                cid2atc_dic[cid].add(atc[:4])
 
# ddi load
ddi_df = pd.read_csv(ddi_file)
ddi_topk_pd = (
    ddi_df.groupby(['Polypharmacy Side Effect', 'Side Effect Name'])
    .size()
    .reset_index(name='count')
    .sort_values('count', ascending=False)
    .tail(TOPK)
)
ddi_df = (
    ddi_df[ddi_df['Side Effect Name'].isin(ddi_topk_pd['Side Effect Name'].tolist())]
    .drop_duplicates(subset=['STITCH 1', 'STITCH 2'])
    .reset_index(drop=True)
)

# weighted ehr adj 
ehr_adj = np.zeros((med_voc_size, med_voc_size))
for patient in records:
    for adm in patient:
        med_set = adm[2]
        for i, med_i in enumerate(med_set):
            for j, med_j in enumerate(med_set):
                if j<=i:
                    continue
                ehr_adj[med_i, med_j] = 1
                ehr_adj[med_j, med_i] = 1
dill.dump(ehr_adj, open('ehr_adj_final.pkl', 'wb'))  

# ddi adj
ddi_adj = np.zeros((med_voc_size,med_voc_size))
for index, row in ddi_df.iterrows():
    # ddi
    cid1 = row['STITCH 1']
    cid2 = row['STITCH 2']
    
    # cid -> atc_level3
    for atc_i in cid2atc_dic[cid1]:
        for atc_j in cid2atc_dic[cid2]:
            
            # atc_level3 -> atc_level4
            for i in atc3_atc4_dic[atc_i]:
                for j in atc3_atc4_dic[atc_j]:
                    if med_voc.word2idx[i] != med_voc.word2idx[j]:
                        ddi_adj[med_voc.word2idx[i], med_voc.word2idx[j]] = 1
                        ddi_adj[med_voc.word2idx[j], med_voc.word2idx[i]] = 1
dill.dump(ddi_adj, open('ddi_A_final.pkl', 'wb')) 
                        
print('Complete!')
# Out:
# Complete!

# %% [markdown]
# ## Part 2: Explore the splitting method's impact on DDI rates
# We had initial difficulties reproducing the paper's results, and we checked the splitting method in the authors' repo. By using some customized code, we calculated the DDI rates in each dataset, including all data, train data, test data, and eval data. If we directly split data using the indices, there are big differences in the various datasets' DDI rates.

# %%
data_path = '../data/records_final.pkl'
data = dill.load(open(data_path, 'rb'))   

split_point = int(len(data) * 2 / 3)                  # 4233
data_train = data[:split_point]                       # 4233 use 67% data for training

eval_len = int(len(data[split_point:]) / 2)           # 1058 divide the rest 33% into eval and test
data_test = data[split_point:split_point + eval_len]  # 1058
data_eval = data[split_point+eval_len:]               # 1059

# %%
all_med = []
for patient in data:
    patient_visit = []
    for visit in patient:
        patient_visit.append(visit[2])        
    all_med.append(patient_visit)

train_med = []
for patient in data_train:
    patient_visit = []
    for visit in patient:
        patient_visit.append(visit[2])        
    train_med.append(patient_visit)

test_med = []
for patient in data_test:
    patient_visit = []
    for visit in patient:
        patient_visit.append(visit[2])        
    test_med.append(patient_visit)
    
val_med = []
for patient in data_eval:
    patient_visit = []
    for visit in patient:
        patient_visit.append(visit[2])        
    val_med.append(patient_visit)

# %%
def ddi_rate_score(record, path='../data/ddi_A_final.pkl'):
    # ddi rate
    ddi_A = dill.load(open(path, 'rb'))
    all_cnt = 0
    dd_cnt = 0
    for patient in record:
        for adm in patient:
            med_code_set = adm
            for i, med_i in enumerate(med_code_set):
                for j, med_j in enumerate(med_code_set):
                    if j <= i:
                        continue
                    all_cnt += 1
                    if ddi_A[med_i, med_j] == 1 or ddi_A[med_j, med_i] == 1:
                        dd_cnt += 1
    if all_cnt == 0:
        return 0
    return dd_cnt / all_cnt

# %%
ddi_rate_score(all_med), ddi_rate_score(train_med), ddi_rate_score(test_med), ddi_rate_score(val_med)
# Out:
# (0.08640852474666356,
#  0.09050506339269059,
#  0.07768553459119497,
#  0.07869765923715379)

# %% [markdown]
# In order to address this uneven dataset issue, we shuffled the dataset and did the indices split. Now the DDI rates among all the datasets are relatively even now. We used the shuffled datasets to train and compared models in the next steps.

# %%
import random
random.seed(1203)

random.shuffle(data)  
data_train = data[:split_point]    
data_test = data[split_point:split_point + eval_len]  
data_eval = data[split_point+eval_len:]

# %%
all_med = []
for patient in data:
    patient_visit = []
    for visit in patient:
        patient_visit.append(visit[2])        
    all_med.append(patient_visit)

train_med = []
for patient in data_train:
    patient_visit = []
    for visit in patient:
        patient_visit.append(visit[2])        
    train_med.append(patient_visit)

test_med = []
for patient in data_test:
    patient_visit = []
    for visit in patient:
        patient_visit.append(visit[2])        
    test_med.append(patient_visit)
    
val_med = []
for patient in data_eval:
    patient_visit = []
    for visit in patient:
        patient_visit.append(visit[2])        
    val_med.append(patient_visit)

ddi_rate_score(all_med), ddi_rate_score(train_med), ddi_rate_score(test_med), ddi_rate_score(val_med)
# Out:
# (0.08640852474666356,
#  0.08665412003769873,
#  0.08676206150376398,
#  0.08512859907741303)

# %% [markdown]
# ## Part 3: Run base models and the GAMENet model
# We directly run the scripts from the command line in order to make the notebook clean. All the codes are in our GitHub repo. For the two GAMENet runs, we used RMSprop as the optimizer, as mentioned in our final report, which showed better performances than the Adam optimizer used in the authors' original repo. Ground truth DDI rate is printed in the run results, so we can calculate DDI rate reduction without ambiguity.

# %%
# %cd ../code
# Out:
# /Users/rachelzou/Documents/Courses/MCS/DLH/Final-Project/RZ-GameNet/code

# %%
# %run baseline_near.py
# Out:
# 	DDI Rate: 0.0885, Jaccard: 0.3722, PRAUC: 0.3570, AVG_PRC: 0.5471, AVG_RECALL: 0.5527, AVG_F1: 0.5256
#
# avg med 14.205563093622795

# %%
# %run train_LR.py
# Out:
# 	DDI Rate: 0.0803, Jaccard: 0.4116, PRAUC: 0.6687, AVG_PRC: 0.6623, AVG_RECALL: 0.5283, AVG_F1: 0.5682
#
# avg med 11.088862559241706

# %%
# %run train_Leap.py --model_name Leap
# Out:
# parameters 436884
# Eval--Epoch: 0, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.1364, Jaccard: 0.3379,  PRAUC: 0.5487, AVG_PRC: 0.4900, AVG_RECALL: 0.5415, AVG_F1: 0.4956
# avg med 14.923879443585781
# 	Epoch: 0, Loss1: 3.2181, One Epoch Time: 2.88m, Appro Left Time: 1.87h
#
# Eval--Epoch: 1, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.1236, Jaccard: 0.3393,  PRAUC: 0.5353, AVG_PRC: 0.4766, AVG_RECALL: 0.5667, AVG_F1: 0.4970
# avg med 16.11321483771252
# 	Epoch: 1, Loss1: 2.9221, One Epoch Time: 2.90m, Appro Left Time: 1.84h
#
# Eval--Epoch: 2, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.1164, Jaccard: 0.3560,  PRAUC: 0.5470, AVG_PRC: 0.5062, AVG_RECALL: 0.5719, AVG_F1: 0.5140
# avg med 15.328438948995363
# 	Epoch: 2, Loss1: 2.8184, One Epoch Time: 2.89m, Appro Left Time: 1.78h
#
# Eval--Epoch: 3, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.1118, Jaccard: 0.3573,  PRAUC: 0.5425, AVG_PRC: 0.5001, AVG_RECALL: 0.5845, AVG_F1: 0.5153
# avg med 15.86707882534776
# 	Epoch: 3, Loss1: 2.7524, One Epoch Time: 2.66m, Appro Left Time: 1.59h
#
# Eval--Epoch: 4, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.1046, Jaccard: 0.3616,  PRAUC: 0.5405, AVG_PRC: 0.5084, AVG_RECALL: 0.5899, AVG_F1: 0.5198
# avg med 15.873647604327665
# 	Epoch: 4, Loss1: 2.7061, One Epoch Time: 2.66m, Appro Left Time: 1.55h
#
# Eval--Epoch: 5, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.1015, Jaccard: 0.3649,  PRAUC: 0.5499, AVG_PRC: 0.5169, AVG_RECALL: 0.5795, AVG_F1: 0.5227
# avg med 15.343508500772797
# 	Epoch: 5, Loss1: 2.6670, One Epoch Time: 2.65m, Appro Left Time: 1.50h
#
# Eval--Epoch: 6, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0903, Jaccard: 0.3696,  PRAUC: 0.5498, AVG_PRC: 0.5132, AVG_RECALL: 0.5914, AVG_F1: 0.5267
# avg med 15.764296754250386
# 	Epoch: 6, Loss1: 2.6356, One Epoch Time: 2.66m, Appro Left Time: 1.46h
#
# Eval--Epoch: 7, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0950, Jaccard: 0.3702,  PRAUC: 0.5487, AVG_PRC: 0.5214, AVG_RECALL: 0.5834, AVG_F1: 0.5271
# avg med 15.39953632148377
# 	Epoch: 7, Loss1: 2.6074, One Epoch Time: 2.65m, Appro Left Time: 1.42h
#
# Eval--Epoch: 8, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.1009, Jaccard: 0.3665,  PRAUC: 0.5470, AVG_PRC: 0.5132, AVG_RECALL: 0.5868, AVG_F1: 0.5234
# avg med 15.734157650695519
# 	Epoch: 8, Loss1: 2.5830, One Epoch Time: 2.68m, Appro Left Time: 1.39h
#
# Eval--Epoch: 9, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0872, Jaccard: 0.3739,  PRAUC: 0.5511, AVG_PRC: 0.5250, AVG_RECALL: 0.5862, AVG_F1: 0.5301
# avg med 15.416924265842349
# 	Epoch: 9, Loss1: 2.5603, One Epoch Time: 2.92m, Appro Left Time: 1.46h
#
# Eval--Epoch: 10, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0914, Jaccard: 0.3721,  PRAUC: 0.5492, AVG_PRC: 0.5207, AVG_RECALL: 0.5868, AVG_F1: 0.5281
# avg med 15.652241112828438
# 	Epoch: 10, Loss1: 2.5406, One Epoch Time: 2.95m, Appro Left Time: 1.43h
#
# Eval--Epoch: 11, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0926, Jaccard: 0.3754,  PRAUC: 0.5546, AVG_PRC: 0.5224, AVG_RECALL: 0.5942, AVG_F1: 0.5323
# avg med 15.775115919629057
# 	Epoch: 11, Loss1: 2.5246, One Epoch Time: 3.01m, Appro Left Time: 1.40h
#
# Eval--Epoch: 12, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0885, Jaccard: 0.3790,  PRAUC: 0.5563, AVG_PRC: 0.5223, AVG_RECALL: 0.5971, AVG_F1: 0.5346
# avg med 15.959428129829984
# 	Epoch: 12, Loss1: 2.5043, One Epoch Time: 2.87m, Appro Left Time: 1.29h
#
# Eval--Epoch: 13, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0895, Jaccard: 0.3758,  PRAUC: 0.5556, AVG_PRC: 0.5237, AVG_RECALL: 0.5890, AVG_F1: 0.5312
# avg med 15.750772797527048
# 	Epoch: 13, Loss1: 2.4904, One Epoch Time: 2.85m, Appro Left Time: 1.24h
#
# Eval--Epoch: 14, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0920, Jaccard: 0.3801,  PRAUC: 0.5607, AVG_PRC: 0.5299, AVG_RECALL: 0.5926, AVG_F1: 0.5364
# avg med 15.566074188562597
# 	Epoch: 14, Loss1: 2.4750, One Epoch Time: 2.81m, Appro Left Time: 1.17h
#
# Eval--Epoch: 15, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0936, Jaccard: 0.3804,  PRAUC: 0.5580, AVG_PRC: 0.5305, AVG_RECALL: 0.5960, AVG_F1: 0.5374
# avg med 15.707882534775889
# 	Epoch: 15, Loss1: 2.4624, One Epoch Time: 2.90m, Appro Left Time: 1.16h
#
# Eval--Epoch: 16, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0904, Jaccard: 0.3827,  PRAUC: 0.5604, AVG_PRC: 0.5313, AVG_RECALL: 0.5981, AVG_F1: 0.5391
# avg med 15.765069551777435
# 	Epoch: 16, Loss1: 2.4478, One Epoch Time: 2.94m, Appro Left Time: 1.13h
#
# Eval--Epoch: 17, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0911, Jaccard: 0.3799,  PRAUC: 0.5592, AVG_PRC: 0.5292, AVG_RECALL: 0.5941, AVG_F1: 0.5358
# avg med 15.743431221020092
# 	Epoch: 17, Loss1: 2.4371, One Epoch Time: 2.93m, Appro Left Time: 1.08h
#
# Eval--Epoch: 18, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0896, Jaccard: 0.3829,  PRAUC: 0.5603, AVG_PRC: 0.5334, AVG_RECALL: 0.5957, AVG_F1: 0.5395
# avg med 15.614374034003092
# 	Epoch: 18, Loss1: 2.4268, One Epoch Time: 2.94m, Appro Left Time: 1.03h
#
# Eval--Epoch: 19, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0911, Jaccard: 0.3813,  PRAUC: 0.5617, AVG_PRC: 0.5313, AVG_RECALL: 0.5945, AVG_F1: 0.5374
# avg med 15.706336939721792
# 	Epoch: 19, Loss1: 2.4148, One Epoch Time: 3.00m, Appro Left Time: 1.00h
#
# Eval--Epoch: 20, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0910, Jaccard: 0.3844,  PRAUC: 0.5634, AVG_PRC: 0.5374, AVG_RECALL: 0.5937, AVG_F1: 0.5408
# avg med 15.454791344667697
# 	Epoch: 20, Loss1: 2.4041, One Epoch Time: 2.96m, Appro Left Time: 0.94h
#
# Eval--Epoch: 21, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0859, Jaccard: 0.3863,  PRAUC: 0.5652, AVG_PRC: 0.5356, AVG_RECALL: 0.6007, AVG_F1: 0.5427
# avg med 15.687789799072643
# 	Epoch: 21, Loss1: 2.3929, One Epoch Time: 2.86m, Appro Left Time: 0.86h
#
# Eval--Epoch: 22, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0906, Jaccard: 0.3842,  PRAUC: 0.5677, AVG_PRC: 0.5314, AVG_RECALL: 0.6001, AVG_F1: 0.5405
# avg med 15.792117465224111
# 	Epoch: 22, Loss1: 2.3837, One Epoch Time: 2.87m, Appro Left Time: 0.81h
#
# Eval--Epoch: 23, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0871, Jaccard: 0.3842,  PRAUC: 0.5642, AVG_PRC: 0.5379, AVG_RECALL: 0.5941, AVG_F1: 0.5401
# avg med 15.509273570324575
# 	Epoch: 23, Loss1: 2.3736, One Epoch Time: 2.88m, Appro Left Time: 0.77h
#
# Eval--Epoch: 24, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0876, Jaccard: 0.3829,  PRAUC: 0.5630, AVG_PRC: 0.5369, AVG_RECALL: 0.5921, AVG_F1: 0.5384
# avg med 15.541344667697063
# 	Epoch: 24, Loss1: 2.3640, One Epoch Time: 2.88m, Appro Left Time: 0.72h
#
# Eval--Epoch: 25, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0847, Jaccard: 0.3816,  PRAUC: 0.5641, AVG_PRC: 0.5360, AVG_RECALL: 0.5889, AVG_F1: 0.5373
# avg med 15.443972179289027
# 	Epoch: 25, Loss1: 2.3554, One Epoch Time: 2.89m, Appro Left Time: 0.67h
#
# Eval--Epoch: 26, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0867, Jaccard: 0.3859,  PRAUC: 0.5672, AVG_PRC: 0.5383, AVG_RECALL: 0.5960, AVG_F1: 0.5414
# avg med 15.547527047913446
# 	Epoch: 26, Loss1: 2.3489, One Epoch Time: 2.65m, Appro Left Time: 0.57h
#
# Eval--Epoch: 27, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0840, Jaccard: 0.3832,  PRAUC: 0.5685, AVG_PRC: 0.5403, AVG_RECALL: 0.5907, AVG_F1: 0.5394
# avg med 15.40919629057187
# 	Epoch: 27, Loss1: 2.3406, One Epoch Time: 2.64m, Appro Left Time: 0.53h
#
# Eval--Epoch: 28, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0843, Jaccard: 0.3819,  PRAUC: 0.5676, AVG_PRC: 0.5341, AVG_RECALL: 0.5926, AVG_F1: 0.5372
# avg med 15.644899536321484
# 	Epoch: 28, Loss1: 2.3304, One Epoch Time: 2.64m, Appro Left Time: 0.48h
#
# Eval--Epoch: 29, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0841, Jaccard: 0.3815,  PRAUC: 0.5692, AVG_PRC: 0.5348, AVG_RECALL: 0.5900, AVG_F1: 0.5373
# avg med 15.496908809891808
# 	Epoch: 29, Loss1: 2.3255, One Epoch Time: 2.65m, Appro Left Time: 0.44h
#
# Eval--Epoch: 30, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0848, Jaccard: 0.3823,  PRAUC: 0.5685, AVG_PRC: 0.5420, AVG_RECALL: 0.5863, AVG_F1: 0.5375
# avg med 15.307959814528594
# 	Epoch: 30, Loss1: 2.3167, One Epoch Time: 2.65m, Appro Left Time: 0.40h
#
# Eval--Epoch: 31, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0816, Jaccard: 0.3868,  PRAUC: 0.5703, AVG_PRC: 0.5432, AVG_RECALL: 0.5932, AVG_F1: 0.5430
# avg med 15.348145285935084
# 	Epoch: 31, Loss1: 2.3110, One Epoch Time: 2.65m, Appro Left Time: 0.35h
# Eval--Epoch: 32, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0809, Jaccard: 0.3817,  PRAUC: 0.5702, AVG_PRC: 0.5406, AVG_RECALL: 0.5850, AVG_F1: 0.5373
# avg med 15.253091190108192
# 	Epoch: 32, Loss1: 2.3019, One Epoch Time: 2.66m, Appro Left Time: 0.31h
#
# Eval--Epoch: 33, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0845, Jaccard: 0.3827,  PRAUC: 0.5662, AVG_PRC: 0.5403, AVG_RECALL: 0.5877, AVG_F1: 0.5385
# avg med 15.326506955177743
# 	Epoch: 33, Loss1: 2.2991, One Epoch Time: 2.66m, Appro Left Time: 0.27h
#
# Eval--Epoch: 34, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0783, Jaccard: 0.3827,  PRAUC: 0.5661, AVG_PRC: 0.5413, AVG_RECALL: 0.5848, AVG_F1: 0.5376
# avg med 15.23338485316847
# 	Epoch: 34, Loss1: 2.2924, One Epoch Time: 2.65m, Appro Left Time: 0.22h
#
# Eval--Epoch: 35, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0809, Jaccard: 0.3825,  PRAUC: 0.5670, AVG_PRC: 0.5423, AVG_RECALL: 0.5847, AVG_F1: 0.5379
# avg med 15.198608964451314
# 	Epoch: 35, Loss1: 2.2877, One Epoch Time: 2.66m, Appro Left Time: 0.18h
#
# Eval--Epoch: 36, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0814, Jaccard: 0.3824,  PRAUC: 0.5659, AVG_PRC: 0.5375, AVG_RECALL: 0.5884, AVG_F1: 0.5373
# avg med 15.365919629057187
# 	Epoch: 36, Loss1: 2.2801, One Epoch Time: 2.65m, Appro Left Time: 0.13h
#
# Eval--Epoch: 37, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0806, Jaccard: 0.3837,  PRAUC: 0.5680, AVG_PRC: 0.5432, AVG_RECALL: 0.5837, AVG_F1: 0.5391
# avg med 15.17967542503864
# 	Epoch: 37, Loss1: 2.2727, One Epoch Time: 2.66m, Appro Left Time: 0.09h
#
# Eval--Epoch: 38, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0839, Jaccard: 0.3845,  PRAUC: 0.5691, AVG_PRC: 0.5495, AVG_RECALL: 0.5804, AVG_F1: 0.5402
# avg med 14.821097372488408
# 	Epoch: 38, Loss1: 2.2690, One Epoch Time: 2.66m, Appro Left Time: 0.04h
#
# Eval--Epoch: 39, Step: 1058/10593	GT DDI Rate: 0.0851, DDI Rate: 0.0809, Jaccard: 0.3819,  PRAUC: 0.5681, AVG_PRC: 0.5409, AVG_RECALL: 0.5815, AVG_F1: 0.5368
# avg med 15.17194744976816
# 	Epoch: 39, Loss1: 2.2624, One Epoch Time: 2.66m, Appro Left Time: 0.00h
#
# best_epoch: 31

# %%
# %run train_Leap.py --model_name Leap --resume_path Epoch_31_JA_0.3868_DDI_0.0816.model --eval
# Out:
# parameters 436884
# Eval--Epoch: 0, Step: 1057/1058	GT DDI Rate: 0.0868, DDI Rate: 0.0851, Jaccard: 0.3809,  PRAUC: 0.5595, AVG_PRC: 0.5345, AVG_RECALL: 0.5872, AVG_F1: 0.5363
# avg med 15.21958925750395

# %%
# %run train_Retain.py --model_name Retain
# Out:
# parameters 289490
# Train--Epoch: 0, Step: 4232/4233
# Eval--Epoch: 0, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0850, Jaccard: 0.3115,  PRAUC: 0.5393, AVG_PRC: 0.3994, AVG_RECALL: 0.6615, AVG_F1: 0.4648
# avg med 22.365598430346633
# 	Epoch: 0, Loss1: 0.8704, One Epoch Time: 0.44m, Appro Left Time: 0.57h
#
# Train--Epoch: 1, Step: 4232/4233
# Eval--Epoch: 1, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0933, Jaccard: 0.3486,  PRAUC: 0.5939, AVG_PRC: 0.4529, AVG_RECALL: 0.6584, AVG_F1: 0.5063
# avg med 19.69718770438195
# 	Epoch: 1, Loss1: 0.5137, One Epoch Time: 0.42m, Appro Left Time: 0.54h
#
# Train--Epoch: 2, Step: 4232/4233
# Eval--Epoch: 2, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0950, Jaccard: 0.3606,  PRAUC: 0.6068, AVG_PRC: 0.4641, AVG_RECALL: 0.6672, AVG_F1: 0.5191
# avg med 19.346631785480707
# 	Epoch: 2, Loss1: 0.4601, One Epoch Time: 0.42m, Appro Left Time: 0.54h
#
# Train--Epoch: 3, Step: 4232/4233
# Eval--Epoch: 3, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0925, Jaccard: 0.3747,  PRAUC: 0.6157, AVG_PRC: 0.5105, AVG_RECALL: 0.6300, AVG_F1: 0.5346
# avg med 16.974493132766515
# 	Epoch: 3, Loss1: 0.4239, One Epoch Time: 0.42m, Appro Left Time: 0.53h
#
# Train--Epoch: 4, Step: 4232/4233
# Eval--Epoch: 4, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0980, Jaccard: 0.3823,  PRAUC: 0.6218, AVG_PRC: 0.5162, AVG_RECALL: 0.6330, AVG_F1: 0.5422
# avg med 16.944408109875734
# 	Epoch: 4, Loss1: 0.3980, One Epoch Time: 0.42m, Appro Left Time: 0.52h
#
# Train--Epoch: 5, Step: 4232/4233
# Eval--Epoch: 5, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0958, Jaccard: 0.3846,  PRAUC: 0.6253, AVG_PRC: 0.5251, AVG_RECALL: 0.6255, AVG_F1: 0.5450
# avg med 16.50490516677567
# 	Epoch: 5, Loss1: 0.3948, One Epoch Time: 0.42m, Appro Left Time: 0.52h
#
# Train--Epoch: 6, Step: 4232/4233
# Eval--Epoch: 6, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0933, Jaccard: 0.3878,  PRAUC: 0.6283, AVG_PRC: 0.5332, AVG_RECALL: 0.6193, AVG_F1: 0.5480
# avg med 16.217789404839763
# 	Epoch: 6, Loss1: 0.3895, One Epoch Time: 0.42m, Appro Left Time: 0.51h
#
# Train--Epoch: 7, Step: 4232/4233
# Eval--Epoch: 7, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0967, Jaccard: 0.3899,  PRAUC: 0.6294, AVG_PRC: 0.5437, AVG_RECALL: 0.6118, AVG_F1: 0.5504
# avg med 15.831262262916939
# 	Epoch: 7, Loss1: 0.3815, One Epoch Time: 0.42m, Appro Left Time: 0.50h
#
# Train--Epoch: 8, Step: 4232/4233
# Eval--Epoch: 8, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0960, Jaccard: 0.3916,  PRAUC: 0.6330, AVG_PRC: 0.5416, AVG_RECALL: 0.6152, AVG_F1: 0.5518
# avg med 16.014388489208635
# 	Epoch: 8, Loss1: 0.3715, One Epoch Time: 0.42m, Appro Left Time: 0.50h
#
# Train--Epoch: 9, Step: 4232/4233
# Eval--Epoch: 9, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0950, Jaccard: 0.3952,  PRAUC: 0.6349, AVG_PRC: 0.5490, AVG_RECALL: 0.6133, AVG_F1: 0.5560
# avg med 15.50490516677567
# 	Epoch: 9, Loss1: 0.3667, One Epoch Time: 0.42m, Appro Left Time: 0.49h
#
# Train--Epoch: 10, Step: 4232/4233
# Eval--Epoch: 10, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.1004, Jaccard: 0.3953,  PRAUC: 0.6341, AVG_PRC: 0.5312, AVG_RECALL: 0.6368, AVG_F1: 0.5553
# avg med 16.606932635709615
# 	Epoch: 10, Loss1: 0.3691, One Epoch Time: 0.42m, Appro Left Time: 0.48h
#
# Train--Epoch: 11, Step: 4232/4233
# Eval--Epoch: 11, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0928, Jaccard: 0.3969,  PRAUC: 0.6369, AVG_PRC: 0.5512, AVG_RECALL: 0.6135, AVG_F1: 0.5574
# avg med 15.542838456507521
# 	Epoch: 11, Loss1: 0.3665, One Epoch Time: 0.42m, Appro Left Time: 0.48h
#
# Train--Epoch: 12, Step: 4232/4233
# Eval--Epoch: 12, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0933, Jaccard: 0.3989,  PRAUC: 0.6369, AVG_PRC: 0.5553, AVG_RECALL: 0.6143, AVG_F1: 0.5594
# avg med 15.39241334205363
# 	Epoch: 12, Loss1: 0.3598, One Epoch Time: 0.44m, Appro Left Time: 0.49h
#
# Train--Epoch: 13, Step: 4232/4233
# Eval--Epoch: 13, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0926, Jaccard: 0.3989,  PRAUC: 0.6390, AVG_PRC: 0.5554, AVG_RECALL: 0.6143, AVG_F1: 0.5596
# avg med 15.601700457815566
# 	Epoch: 13, Loss1: 0.3556, One Epoch Time: 0.43m, Appro Left Time: 0.47h
#
# Train--Epoch: 14, Step: 4232/4233
# Eval--Epoch: 14, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0975, Jaccard: 0.4008,  PRAUC: 0.6397, AVG_PRC: 0.5457, AVG_RECALL: 0.6294, AVG_F1: 0.5611
# avg med 16.283191628515368
# 	Epoch: 14, Loss1: 0.3537, One Epoch Time: 0.42m, Appro Left Time: 0.45h
#
# Train--Epoch: 15, Step: 4232/4233
# Eval--Epoch: 15, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0935, Jaccard: 0.4015,  PRAUC: 0.6405, AVG_PRC: 0.5640, AVG_RECALL: 0.6091, AVG_F1: 0.5620
# avg med 14.977763243950294
# 	Epoch: 15, Loss1: 0.3498, One Epoch Time: 0.41m, Appro Left Time: 0.44h
#
# Train--Epoch: 16, Step: 4232/4233
# Eval--Epoch: 16, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0902, Jaccard: 0.4028,  PRAUC: 0.6415, AVG_PRC: 0.5611, AVG_RECALL: 0.6138, AVG_F1: 0.5633
# avg med 15.206017004578156
# 	Epoch: 16, Loss1: 0.3574, One Epoch Time: 0.41m, Appro Left Time: 0.43h
#
# Train--Epoch: 17, Step: 4232/4233
# Eval--Epoch: 17, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0937, Jaccard: 0.4018,  PRAUC: 0.6415, AVG_PRC: 0.5609, AVG_RECALL: 0.6114, AVG_F1: 0.5620
# avg med 15.423152387181164
# 	Epoch: 17, Loss1: 0.3522, One Epoch Time: 0.41m, Appro Left Time: 0.43h
#
# Train--Epoch: 18, Step: 4232/4233
# Eval--Epoch: 18, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0945, Jaccard: 0.4050,  PRAUC: 0.6441, AVG_PRC: 0.5536, AVG_RECALL: 0.6263, AVG_F1: 0.5651
# avg med 15.754741661216482
# 	Epoch: 18, Loss1: 0.3474, One Epoch Time: 0.41m, Appro Left Time: 0.41h
#
# Train--Epoch: 19, Step: 4232/4233
# Eval--Epoch: 19, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0945, Jaccard: 0.4048,  PRAUC: 0.6442, AVG_PRC: 0.5604, AVG_RECALL: 0.6187, AVG_F1: 0.5652
# avg med 15.421844342707653
# 	Epoch: 19, Loss1: 0.3460, One Epoch Time: 0.41m, Appro Left Time: 0.41h
#
# Train--Epoch: 20, Step: 4232/4233
# Eval--Epoch: 20, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0964, Jaccard: 0.4045,  PRAUC: 0.6444, AVG_PRC: 0.5611, AVG_RECALL: 0.6176, AVG_F1: 0.5648
# avg med 15.350555918901243
# 	Epoch: 20, Loss1: 0.3455, One Epoch Time: 0.40m, Appro Left Time: 0.39h
#
# Train--Epoch: 21, Step: 4232/4233
# Eval--Epoch: 21, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0912, Jaccard: 0.4061,  PRAUC: 0.6452, AVG_PRC: 0.5633, AVG_RECALL: 0.6178, AVG_F1: 0.5664
# avg med 15.340091563113146
# 	Epoch: 21, Loss1: 0.3461, One Epoch Time: 0.40m, Appro Left Time: 0.38h
#
# Train--Epoch: 22, Step: 4232/4233
# Eval--Epoch: 22, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0985, Jaccard: 0.4053,  PRAUC: 0.6450, AVG_PRC: 0.5596, AVG_RECALL: 0.6224, AVG_F1: 0.5657
# avg med 15.417266187050359
# 	Epoch: 22, Loss1: 0.3440, One Epoch Time: 0.40m, Appro Left Time: 0.38h
#
# Train--Epoch: 23, Step: 4232/4233
# Eval--Epoch: 23, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0939, Jaccard: 0.4081,  PRAUC: 0.6460, AVG_PRC: 0.5674, AVG_RECALL: 0.6189, AVG_F1: 0.5684
# avg med 15.067364290385873
# 	Epoch: 23, Loss1: 0.3411, One Epoch Time: 0.40m, Appro Left Time: 0.37h
#
# Train--Epoch: 24, Step: 4232/4233
# Eval--Epoch: 24, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0959, Jaccard: 0.4083,  PRAUC: 0.6471, AVG_PRC: 0.5667, AVG_RECALL: 0.6201, AVG_F1: 0.5686
# avg med 15.168737737083061
# 	Epoch: 24, Loss1: 0.3396, One Epoch Time: 0.39m, Appro Left Time: 0.36h
#
# Train--Epoch: 25, Step: 4232/4233
# Eval--Epoch: 25, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0925, Jaccard: 0.4077,  PRAUC: 0.6459, AVG_PRC: 0.5602, AVG_RECALL: 0.6258, AVG_F1: 0.5681
# avg med 15.672988881621976
# 	Epoch: 25, Loss1: 0.3387, One Epoch Time: 0.46m, Appro Left Time: 0.42h
#
# Train--Epoch: 26, Step: 4232/4233
# Eval--Epoch: 26, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0964, Jaccard: 0.4090,  PRAUC: 0.6469, AVG_PRC: 0.5589, AVG_RECALL: 0.6305, AVG_F1: 0.5693
# avg med 15.822105951602355
# 	Epoch: 26, Loss1: 0.3400, One Epoch Time: 0.40m, Appro Left Time: 0.35h
#
# Train--Epoch: 27, Step: 4232/4233
# Eval--Epoch: 27, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0917, Jaccard: 0.4092,  PRAUC: 0.6492, AVG_PRC: 0.5686, AVG_RECALL: 0.6179, AVG_F1: 0.5695
# avg med 15.04120340091563
# 	Epoch: 27, Loss1: 0.3372, One Epoch Time: 0.41m, Appro Left Time: 0.35h
#
# Train--Epoch: 28, Step: 4232/4233
# Eval--Epoch: 28, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0922, Jaccard: 0.4078,  PRAUC: 0.6475, AVG_PRC: 0.5669, AVG_RECALL: 0.6168, AVG_F1: 0.5681
# avg med 15.089601046435579
# 	Epoch: 28, Loss1: 0.3415, One Epoch Time: 0.40m, Appro Left Time: 0.34h
#
# Train--Epoch: 29, Step: 4232/4233
# Eval--Epoch: 29, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0954, Jaccard: 0.4101,  PRAUC: 0.6478, AVG_PRC: 0.5632, AVG_RECALL: 0.6259, AVG_F1: 0.5703
# avg med 15.487246566383257
# 	Epoch: 29, Loss1: 0.3356, One Epoch Time: 0.40m, Appro Left Time: 0.33h
#
# Train--Epoch: 30, Step: 4232/4233
# Eval--Epoch: 30, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0953, Jaccard: 0.4095,  PRAUC: 0.6489, AVG_PRC: 0.5742, AVG_RECALL: 0.6131, AVG_F1: 0.5699
# avg med 14.734466971877044
# 	Epoch: 30, Loss1: 0.3327, One Epoch Time: 0.40m, Appro Left Time: 0.32h
#
# Train--Epoch: 31, Step: 4232/4233
# Eval--Epoch: 31, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0940, Jaccard: 0.4106,  PRAUC: 0.6478, AVG_PRC: 0.5641, AVG_RECALL: 0.6263, AVG_F1: 0.5709
# avg med 15.62916939175932
# 	Epoch: 31, Loss1: 0.3314, One Epoch Time: 0.39m, Appro Left Time: 0.31h
#
# Train--Epoch: 32, Step: 4232/4233
# Eval--Epoch: 32, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0923, Jaccard: 0.4104,  PRAUC: 0.6495, AVG_PRC: 0.5726, AVG_RECALL: 0.6156, AVG_F1: 0.5705
# avg med 14.936559843034663
# 	Epoch: 32, Loss1: 0.3356, One Epoch Time: 0.40m, Appro Left Time: 0.32h
#
# Train--Epoch: 33, Step: 4232/4233
# Eval--Epoch: 33, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0935, Jaccard: 0.4107,  PRAUC: 0.6494, AVG_PRC: 0.5714, AVG_RECALL: 0.6182, AVG_F1: 0.5709
# avg med 15.056899934597777
# 	Epoch: 33, Loss1: 0.3307, One Epoch Time: 0.38m, Appro Left Time: 0.29h
#
# Train--Epoch: 34, Step: 4232/4233
# Eval--Epoch: 34, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0914, Jaccard: 0.4116,  PRAUC: 0.6499, AVG_PRC: 0.5671, AVG_RECALL: 0.6253, AVG_F1: 0.5716
# avg med 15.306082406801831
# 	Epoch: 34, Loss1: 0.3307, One Epoch Time: 0.39m, Appro Left Time: 0.29h
#
# Train--Epoch: 35, Step: 4232/4233
# Eval--Epoch: 35, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0973, Jaccard: 0.4116,  PRAUC: 0.6501, AVG_PRC: 0.5636, AVG_RECALL: 0.6298, AVG_F1: 0.5718
# avg med 15.60104643557881
# 	Epoch: 35, Loss1: 0.3306, One Epoch Time: 0.39m, Appro Left Time: 0.28h
#
# Train--Epoch: 36, Step: 4232/4233
# Eval--Epoch: 36, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0907, Jaccard: 0.4115,  PRAUC: 0.6507, AVG_PRC: 0.5750, AVG_RECALL: 0.6156, AVG_F1: 0.5717
# avg med 14.944408109875736
# 	Epoch: 36, Loss1: 0.3318, One Epoch Time: 0.44m, Appro Left Time: 0.32h
#
# Train--Epoch: 37, Step: 4232/4233
# Eval--Epoch: 37, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0931, Jaccard: 0.4133,  PRAUC: 0.6505, AVG_PRC: 0.5732, AVG_RECALL: 0.6211, AVG_F1: 0.5732
# avg med 15.015042511445388
# 	Epoch: 37, Loss1: 0.3263, One Epoch Time: 0.42m, Appro Left Time: 0.30h
#
# Train--Epoch: 38, Step: 4232/4233
# Eval--Epoch: 38, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0930, Jaccard: 0.4127,  PRAUC: 0.6514, AVG_PRC: 0.5753, AVG_RECALL: 0.6189, AVG_F1: 0.5729
# avg med 15.009156311314584
# 	Epoch: 38, Loss1: 0.3273, One Epoch Time: 0.41m, Appro Left Time: 0.28h
#
# Train--Epoch: 39, Step: 4232/4233
# Eval--Epoch: 39, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0913, Jaccard: 0.4134,  PRAUC: 0.6514, AVG_PRC: 0.5730, AVG_RECALL: 0.6209, AVG_F1: 0.5734
# avg med 15.088947024198823
# 	Epoch: 39, Loss1: 0.3259, One Epoch Time: 0.40m, Appro Left Time: 0.26h
#
# Train--Epoch: 40, Step: 4232/4233
# Eval--Epoch: 40, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0930, Jaccard: 0.4130,  PRAUC: 0.6513, AVG_PRC: 0.5716, AVG_RECALL: 0.6233, AVG_F1: 0.5732
# avg med 15.17724002616089
# 	Epoch: 40, Loss1: 0.3274, One Epoch Time: 0.39m, Appro Left Time: 0.26h
#
# Train--Epoch: 41, Step: 4232/4233
# Eval--Epoch: 41, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0929, Jaccard: 0.4151,  PRAUC: 0.6528, AVG_PRC: 0.5699, AVG_RECALL: 0.6287, AVG_F1: 0.5749
# avg med 15.357096141268803
# 	Epoch: 41, Loss1: 0.3278, One Epoch Time: 0.40m, Appro Left Time: 0.25h
#
# Train--Epoch: 42, Step: 4232/4233
# Eval--Epoch: 42, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0904, Jaccard: 0.4144,  PRAUC: 0.6520, AVG_PRC: 0.5750, AVG_RECALL: 0.6220, AVG_F1: 0.5744
# avg med 15.037279267495094
# 	Epoch: 42, Loss1: 0.3275, One Epoch Time: 0.42m, Appro Left Time: 0.26h
#
# Train--Epoch: 43, Step: 4232/4233
# Eval--Epoch: 43, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0928, Jaccard: 0.4150,  PRAUC: 0.6524, AVG_PRC: 0.5709, AVG_RECALL: 0.6261, AVG_F1: 0.5744
# avg med 15.304774362328319
# 	Epoch: 43, Loss1: 0.3232, One Epoch Time: 0.45m, Appro Left Time: 0.27h
#
# Train--Epoch: 44, Step: 4232/4233
# Eval--Epoch: 44, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0940, Jaccard: 0.4141,  PRAUC: 0.6516, AVG_PRC: 0.5587, AVG_RECALL: 0.6407, AVG_F1: 0.5740
# avg med 15.952256376716809
# 	Epoch: 44, Loss1: 0.3264, One Epoch Time: 0.43m, Appro Left Time: 0.25h
#
# Train--Epoch: 45, Step: 4232/4233
# Eval--Epoch: 45, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0917, Jaccard: 0.4140,  PRAUC: 0.6514, AVG_PRC: 0.5736, AVG_RECALL: 0.6227, AVG_F1: 0.5737
# avg med 15.047743623283191
# 	Epoch: 45, Loss1: 0.3261, One Epoch Time: 0.41m, Appro Left Time: 0.23h
#
# Train--Epoch: 46, Step: 4232/4233
# Eval--Epoch: 46, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0917, Jaccard: 0.4139,  PRAUC: 0.6526, AVG_PRC: 0.5681, AVG_RECALL: 0.6273, AVG_F1: 0.5738
# avg med 15.360366252452584
# 	Epoch: 46, Loss1: 0.3216, One Epoch Time: 0.45m, Appro Left Time: 0.25h
#
# Train--Epoch: 47, Step: 4232/4233
# Eval--Epoch: 47, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0924, Jaccard: 0.4154,  PRAUC: 0.6535, AVG_PRC: 0.5733, AVG_RECALL: 0.6266, AVG_F1: 0.5754
# avg med 15.18705035971223
# 	Epoch: 47, Loss1: 0.3205, One Epoch Time: 0.46m, Appro Left Time: 0.24h
#
# Train--Epoch: 48, Step: 4232/4233
# Eval--Epoch: 48, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0906, Jaccard: 0.4155,  PRAUC: 0.6529, AVG_PRC: 0.5678, AVG_RECALL: 0.6326, AVG_F1: 0.5754
# avg med 15.483322432962721
# 	Epoch: 48, Loss1: 0.3226, One Epoch Time: 0.45m, Appro Left Time: 0.23h
#
# Train--Epoch: 49, Step: 4232/4233
# Eval--Epoch: 49, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0890, Jaccard: 0.4151,  PRAUC: 0.6525, AVG_PRC: 0.5757, AVG_RECALL: 0.6222, AVG_F1: 0.5749
# avg med 15.09287115761936
# 	Epoch: 49, Loss1: 0.3221, One Epoch Time: 0.44m, Appro Left Time: 0.22h
#
# Train--Epoch: 50, Step: 4232/4233
# Eval--Epoch: 50, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0926, Jaccard: 0.4160,  PRAUC: 0.6533, AVG_PRC: 0.5709, AVG_RECALL: 0.6314, AVG_F1: 0.5760
# avg med 15.46697187704382
# 	Epoch: 50, Loss1: 0.3223, One Epoch Time: 0.53m, Appro Left Time: 0.25h
#
# Train--Epoch: 51, Step: 4232/4233
# Eval--Epoch: 51, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0893, Jaccard: 0.4153,  PRAUC: 0.6536, AVG_PRC: 0.5767, AVG_RECALL: 0.6210, AVG_F1: 0.5749
# avg med 14.897972531066056
# 	Epoch: 51, Loss1: 0.3232, One Epoch Time: 0.41m, Appro Left Time: 0.19h
#
# Train--Epoch: 52, Step: 4232/4233
# Eval--Epoch: 52, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0917, Jaccard: 0.4160,  PRAUC: 0.6534, AVG_PRC: 0.5724, AVG_RECALL: 0.6279, AVG_F1: 0.5760
# avg med 15.204708960104643
# 	Epoch: 52, Loss1: 0.3199, One Epoch Time: 0.44m, Appro Left Time: 0.20h
#
# Train--Epoch: 53, Step: 4232/4233
# Eval--Epoch: 53, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0899, Jaccard: 0.4153,  PRAUC: 0.6529, AVG_PRC: 0.5734, AVG_RECALL: 0.6258, AVG_F1: 0.5750
# avg med 15.24983649444081
# 	Epoch: 53, Loss1: 0.3165, One Epoch Time: 0.40m, Appro Left Time: 0.18h
#
# Train--Epoch: 54, Step: 4232/4233
# Eval--Epoch: 54, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0909, Jaccard: 0.4159,  PRAUC: 0.6525, AVG_PRC: 0.5742, AVG_RECALL: 0.6273, AVG_F1: 0.5759
# avg med 15.124918247220405
# 	Epoch: 54, Loss1: 0.3185, One Epoch Time: 0.40m, Appro Left Time: 0.17h
#
# Train--Epoch: 55, Step: 4232/4233
# Eval--Epoch: 55, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0895, Jaccard: 0.4170,  PRAUC: 0.6536, AVG_PRC: 0.5739, AVG_RECALL: 0.6288, AVG_F1: 0.5768
# avg med 15.257030739045128
# 	Epoch: 55, Loss1: 0.3180, One Epoch Time: 0.40m, Appro Left Time: 0.16h
#
# Train--Epoch: 56, Step: 4232/4233
# Eval--Epoch: 56, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0901, Jaccard: 0.4145,  PRAUC: 0.6543, AVG_PRC: 0.5739, AVG_RECALL: 0.6238, AVG_F1: 0.5744
# avg med 15.224329627207325
# 	Epoch: 56, Loss1: 0.3158, One Epoch Time: 0.40m, Appro Left Time: 0.15h
#
# Train--Epoch: 57, Step: 4232/4233
# Eval--Epoch: 57, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0932, Jaccard: 0.4172,  PRAUC: 0.6527, AVG_PRC: 0.5664, AVG_RECALL: 0.6380, AVG_F1: 0.5768
# avg med 15.710922171353825
# 	Epoch: 57, Loss1: 0.3189, One Epoch Time: 0.40m, Appro Left Time: 0.15h
#
# Train--Epoch: 58, Step: 4232/4233
# Eval--Epoch: 58, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0890, Jaccard: 0.4161,  PRAUC: 0.6537, AVG_PRC: 0.5728, AVG_RECALL: 0.6270, AVG_F1: 0.5758
# avg med 15.424460431654676
# 	Epoch: 58, Loss1: 0.3169, One Epoch Time: 0.40m, Appro Left Time: 0.14h
#
# Train--Epoch: 59, Step: 4232/4233
# Eval--Epoch: 59, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0911, Jaccard: 0.4165,  PRAUC: 0.6539, AVG_PRC: 0.5713, AVG_RECALL: 0.6317, AVG_F1: 0.5766
# avg med 15.481360366252453
# 	Epoch: 59, Loss1: 0.3156, One Epoch Time: 0.40m, Appro Left Time: 0.13h
#
# Train--Epoch: 60, Step: 4232/4233
# Eval--Epoch: 60, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0894, Jaccard: 0.4170,  PRAUC: 0.6541, AVG_PRC: 0.5719, AVG_RECALL: 0.6307, AVG_F1: 0.5769
# avg med 15.335513407455853
# 	Epoch: 60, Loss1: 0.3165, One Epoch Time: 0.40m, Appro Left Time: 0.13h
#
# Train--Epoch: 61, Step: 4232/4233
# Eval--Epoch: 61, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0891, Jaccard: 0.4162,  PRAUC: 0.6537, AVG_PRC: 0.5727, AVG_RECALL: 0.6288, AVG_F1: 0.5763
# avg med 15.379986919555265
# 	Epoch: 61, Loss1: 0.3142, One Epoch Time: 0.40m, Appro Left Time: 0.12h
#
# Train--Epoch: 62, Step: 4232/4233
# Eval--Epoch: 62, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0888, Jaccard: 0.4167,  PRAUC: 0.6549, AVG_PRC: 0.5727, AVG_RECALL: 0.6300, AVG_F1: 0.5767
# avg med 15.394375408763898
# 	Epoch: 62, Loss1: 0.3163, One Epoch Time: 0.40m, Appro Left Time: 0.11h
#
# Train--Epoch: 63, Step: 4232/4233
# Eval--Epoch: 63, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0898, Jaccard: 0.4159,  PRAUC: 0.6542, AVG_PRC: 0.5731, AVG_RECALL: 0.6282, AVG_F1: 0.5756
# avg med 15.31785480706344
# 	Epoch: 63, Loss1: 0.3143, One Epoch Time: 0.40m, Appro Left Time: 0.11h
#
# Train--Epoch: 64, Step: 4232/4233
# Eval--Epoch: 64, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0871, Jaccard: 0.4171,  PRAUC: 0.6539, AVG_PRC: 0.5742, AVG_RECALL: 0.6308, AVG_F1: 0.5773
# avg med 15.20209287115762
# 	Epoch: 64, Loss1: 0.3149, One Epoch Time: 0.40m, Appro Left Time: 0.10h
#
# Train--Epoch: 65, Step: 4232/4233
# Eval--Epoch: 65, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0895, Jaccard: 0.4170,  PRAUC: 0.6531, AVG_PRC: 0.5739, AVG_RECALL: 0.6307, AVG_F1: 0.5769
# avg med 15.357096141268803
# 	Epoch: 65, Loss1: 0.3124, One Epoch Time: 0.40m, Appro Left Time: 0.09h
#
# Train--Epoch: 66, Step: 4232/4233
# Eval--Epoch: 66, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0888, Jaccard: 0.4158,  PRAUC: 0.6533, AVG_PRC: 0.5692, AVG_RECALL: 0.6323, AVG_F1: 0.5757
# avg med 15.558534990189667
# 	Epoch: 66, Loss1: 0.3133, One Epoch Time: 0.40m, Appro Left Time: 0.09h
#
# Train--Epoch: 67, Step: 4232/4233
# Eval--Epoch: 67, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0881, Jaccard: 0.4176,  PRAUC: 0.6537, AVG_PRC: 0.5706, AVG_RECALL: 0.6342, AVG_F1: 0.5776
# avg med 15.537606278613472
# 	Epoch: 67, Loss1: 0.3125, One Epoch Time: 0.40m, Appro Left Time: 0.08h
#
# Train--Epoch: 68, Step: 4232/4233
# Eval--Epoch: 68, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0904, Jaccard: 0.4157,  PRAUC: 0.6536, AVG_PRC: 0.5750, AVG_RECALL: 0.6254, AVG_F1: 0.5755
# avg med 15.321778940483977
# 	Epoch: 68, Loss1: 0.3134, One Epoch Time: 0.39m, Appro Left Time: 0.07h
#
# Train--Epoch: 69, Step: 4232/4233
# Eval--Epoch: 69, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0882, Jaccard: 0.4155,  PRAUC: 0.6542, AVG_PRC: 0.5724, AVG_RECALL: 0.6269, AVG_F1: 0.5753
# avg med 15.357750163505559
# 	Epoch: 69, Loss1: 0.3125, One Epoch Time: 0.38m, Appro Left Time: 0.06h
#
# Train--Epoch: 70, Step: 4232/4233
# Eval--Epoch: 70, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0895, Jaccard: 0.4160,  PRAUC: 0.6541, AVG_PRC: 0.5705, AVG_RECALL: 0.6298, AVG_F1: 0.5755
# avg med 15.474166121648135
# 	Epoch: 70, Loss1: 0.3119, One Epoch Time: 0.38m, Appro Left Time: 0.06h
#
# Train--Epoch: 71, Step: 4232/4233
# Eval--Epoch: 71, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0883, Jaccard: 0.4171,  PRAUC: 0.6540, AVG_PRC: 0.5722, AVG_RECALL: 0.6315, AVG_F1: 0.5768
# avg med 15.570961412688032
# 	Epoch: 71, Loss1: 0.3099, One Epoch Time: 0.38m, Appro Left Time: 0.05h
#
# Train--Epoch: 72, Step: 4232/4233
# Eval--Epoch: 72, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0877, Jaccard: 0.4162,  PRAUC: 0.6532, AVG_PRC: 0.5752, AVG_RECALL: 0.6263, AVG_F1: 0.5761
# avg med 15.280575539568344
# 	Epoch: 72, Loss1: 0.3092, One Epoch Time: 0.38m, Appro Left Time: 0.04h
#
# Train--Epoch: 73, Step: 4232/4233
# Eval--Epoch: 73, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0898, Jaccard: 0.4166,  PRAUC: 0.6535, AVG_PRC: 0.5646, AVG_RECALL: 0.6401, AVG_F1: 0.5765
# avg med 15.906474820143885
# 	Epoch: 73, Loss1: 0.3093, One Epoch Time: 0.38m, Appro Left Time: 0.04h
#
# Train--Epoch: 74, Step: 4232/4233
# Eval--Epoch: 74, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0910, Jaccard: 0.4171,  PRAUC: 0.6535, AVG_PRC: 0.5736, AVG_RECALL: 0.6308, AVG_F1: 0.5769
# avg med 15.357750163505559
# 	Epoch: 74, Loss1: 0.3091, One Epoch Time: 0.38m, Appro Left Time: 0.03h
#
# Train--Epoch: 75, Step: 4232/4233
# Eval--Epoch: 75, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0905, Jaccard: 0.4151,  PRAUC: 0.6528, AVG_PRC: 0.5733, AVG_RECALL: 0.6262, AVG_F1: 0.5749
# avg med 15.230869849574885
# 	Epoch: 75, Loss1: 0.3106, One Epoch Time: 0.38m, Appro Left Time: 0.03h
#
# Train--Epoch: 76, Step: 4232/4233
# Eval--Epoch: 76, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0915, Jaccard: 0.4169,  PRAUC: 0.6530, AVG_PRC: 0.5710, AVG_RECALL: 0.6326, AVG_F1: 0.5767
# avg med 15.4865925441465
# 	Epoch: 76, Loss1: 0.3094, One Epoch Time: 0.38m, Appro Left Time: 0.02h
#
# Train--Epoch: 77, Step: 4232/4233
# Eval--Epoch: 77, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0899, Jaccard: 0.4156,  PRAUC: 0.6542, AVG_PRC: 0.5704, AVG_RECALL: 0.6297, AVG_F1: 0.5750
# avg med 15.515369522563768
# 	Epoch: 77, Loss1: 0.3084, One Epoch Time: 0.38m, Appro Left Time: 0.01h
#
# Train--Epoch: 78, Step: 4232/4233
# Eval--Epoch: 78, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0898, Jaccard: 0.4168,  PRAUC: 0.6534, AVG_PRC: 0.5703, AVG_RECALL: 0.6333, AVG_F1: 0.5766
# avg med 15.453891432308698
# 	Epoch: 78, Loss1: 0.3097, One Epoch Time: 0.38m, Appro Left Time: 0.01h
#
# Train--Epoch: 79, Step: 4232/4233
# Eval--Epoch: 79, Step: 1058/1059	GT DDI Rate: 0.0876, DDI Rate: 0.0902, Jaccard: 0.4168,  PRAUC: 0.6525, AVG_PRC: 0.5703, AVG_RECALL: 0.6314, AVG_F1: 0.5761
# avg med 15.657946370176585
# 	Epoch: 79, Loss1: 0.3101, One Epoch Time: 0.41m, Appro Left Time: 0.00h
#
# best_epoch: 67

# %%
# %run train_Retain.py --model_name Retain --resume_path Epoch_67_JA_0.4176_DDI_0.0881.model --eval
# Out:
# parameters 289490
#
# Eval--Epoch: 0, Step: 1057/1058	GT DDI Rate: 0.0877, DDI Rate: 0.0914, Jaccard: 0.4132,  PRAUC: 0.6482, AVG_PRC: 0.5588, AVG_RECALL: 0.6345, AVG_F1: 0.5724
# avg med 15.614654002713705

# %%
# %run train_GAMENet.py --model_name GAMENet --ddi
# Out:
# parameters 536534
# Eval--Epoch: 0, Step: 1058/10593, L_p cnt: 6754, L_neg cnt: 3142	GT DDI Rate: 0.0851, DDI Rate: 0.0398, Jaccard: 0.3418,  PRAUC: 0.6060, AVG_PRC: 0.6724, AVG_RECALL: 0.4240, AVG_F1: 0.5005
# avg med 8.311823802163833
# 	Epoch: 0, Loss: 0.1759, One Epoch Time: 1.74m, Appro Left Time: 1.13h
#
# Eval--Epoch: 1, Step: 1058/10593, L_p cnt: 8652, L_neg cnt: 1244	GT DDI Rate: 0.0851, DDI Rate: 0.0460, Jaccard: 0.3637,  PRAUC: 0.6157, AVG_PRC: 0.6471, AVG_RECALL: 0.4688, AVG_F1: 0.5237
# avg med 9.688948995363214
# 	Epoch: 1, Loss: 0.2205, One Epoch Time: 1.72m, Appro Left Time: 1.09h
#
# Eval--Epoch: 2, Step: 1058/10593, L_p cnt: 7925, L_neg cnt: 1971	GT DDI Rate: 0.0851, DDI Rate: 0.0400, Jaccard: 0.3726,  PRAUC: 0.6245, AVG_PRC: 0.6508, AVG_RECALL: 0.4792, AVG_F1: 0.5329
# avg med 9.744976816074189
# 	Epoch: 2, Loss: 0.1973, One Epoch Time: 1.94m, Appro Left Time: 1.20h
#
# Eval--Epoch: 3, Step: 1058/10593, L_p cnt: 7619, L_neg cnt: 2277	GT DDI Rate: 0.0851, DDI Rate: 0.0445, Jaccard: 0.3756,  PRAUC: 0.6299, AVG_PRC: 0.6542, AVG_RECALL: 0.4816, AVG_F1: 0.5359
# avg med 9.729134466769706
# 	Epoch: 3, Loss: 0.1861, One Epoch Time: 2.02m, Appro Left Time: 1.21h
#
# Eval--Epoch: 4, Step: 1058/10593, L_p cnt: 6939, L_neg cnt: 2957	GT DDI Rate: 0.0851, DDI Rate: 0.0492, Jaccard: 0.3778,  PRAUC: 0.6351, AVG_PRC: 0.6601, AVG_RECALL: 0.4814, AVG_F1: 0.5380
# avg med 9.667310664605873
# 	Epoch: 4, Loss: 0.1668, One Epoch Time: 1.99m, Appro Left Time: 1.16h
#
# Eval--Epoch: 5, Step: 1058/10593, L_p cnt: 6340, L_neg cnt: 3556	GT DDI Rate: 0.0851, DDI Rate: 0.0508, Jaccard: 0.3894,  PRAUC: 0.6390, AVG_PRC: 0.6601, AVG_RECALL: 0.4979, AVG_F1: 0.5487
# avg med 9.978748068006182
# 	Epoch: 5, Loss: 0.1501, One Epoch Time: 2.01m, Appro Left Time: 1.14h
#
# Eval--Epoch: 6, Step: 1058/10593, L_p cnt: 6205, L_neg cnt: 3691	GT DDI Rate: 0.0851, DDI Rate: 0.0567, Jaccard: 0.3982,  PRAUC: 0.6445, AVG_PRC: 0.6638, AVG_RECALL: 0.5088, AVG_F1: 0.5567
# avg med 10.169242658423492
# 	Epoch: 6, Loss: 0.1460, One Epoch Time: 2.03m, Appro Left Time: 1.12h
#
# Eval--Epoch: 7, Step: 1058/10593, L_p cnt: 6132, L_neg cnt: 3764	GT DDI Rate: 0.0851, DDI Rate: 0.0593, Jaccard: 0.4020,  PRAUC: 0.6516, AVG_PRC: 0.6676, AVG_RECALL: 0.5112, AVG_F1: 0.5601
# avg med 10.17465224111283
# 	Epoch: 7, Loss: 0.1437, One Epoch Time: 1.94m, Appro Left Time: 1.04h
#
# Eval--Epoch: 8, Step: 1058/10593, L_p cnt: 6045, L_neg cnt: 3851	GT DDI Rate: 0.0851, DDI Rate: 0.0506, Jaccard: 0.4058,  PRAUC: 0.6553, AVG_PRC: 0.6633, AVG_RECALL: 0.5201, AVG_F1: 0.5640
# avg med 10.420788253477589
# 	Epoch: 8, Loss: 0.1412, One Epoch Time: 2.01m, Appro Left Time: 1.04h
#
# Eval--Epoch: 9, Step: 1058/10593, L_p cnt: 6336, L_neg cnt: 3560	GT DDI Rate: 0.0851, DDI Rate: 0.0564, Jaccard: 0.4095,  PRAUC: 0.6589, AVG_PRC: 0.6578, AVG_RECALL: 0.5293, AVG_F1: 0.5675
# avg med 10.71097372488408
# 	Epoch: 9, Loss: 0.1452, One Epoch Time: 2.07m, Appro Left Time: 1.03h
#
# Eval--Epoch: 10, Step: 1058/10593, L_p cnt: 6365, L_neg cnt: 3531	GT DDI Rate: 0.0851, DDI Rate: 0.0582, Jaccard: 0.4121,  PRAUC: 0.6614, AVG_PRC: 0.6569, AVG_RECALL: 0.5339, AVG_F1: 0.5698
# avg med 10.832689335394127
# 	Epoch: 10, Loss: 0.1462, One Epoch Time: 1.93m, Appro Left Time: 0.93h
#
# Eval--Epoch: 11, Step: 1058/10593, L_p cnt: 6686, L_neg cnt: 3210	GT DDI Rate: 0.0851, DDI Rate: 0.0552, Jaccard: 0.4135,  PRAUC: 0.6627, AVG_PRC: 0.6634, AVG_RECALL: 0.5312, AVG_F1: 0.5711
# avg med 10.682766615146832
# 	Epoch: 11, Loss: 0.1529, One Epoch Time: 1.85m, Appro Left Time: 0.86h
#
# Eval--Epoch: 12, Step: 1058/10593, L_p cnt: 6929, L_neg cnt: 2967	GT DDI Rate: 0.0851, DDI Rate: 0.0615, Jaccard: 0.4144,  PRAUC: 0.6656, AVG_PRC: 0.6622, AVG_RECALL: 0.5327, AVG_F1: 0.5718
# avg med 10.730680061823803
# 	Epoch: 12, Loss: 0.1568, One Epoch Time: 1.85m, Appro Left Time: 0.83h
#
# Eval--Epoch: 13, Step: 1058/10593, L_p cnt: 7216, L_neg cnt: 2680	GT DDI Rate: 0.0851, DDI Rate: 0.0659, Jaccard: 0.4176,  PRAUC: 0.6661, AVG_PRC: 0.6542, AVG_RECALL: 0.5443, AVG_F1: 0.5753
# avg med 11.089258114374035
# 	Epoch: 13, Loss: 0.1632, One Epoch Time: 1.80m, Appro Left Time: 0.78h
#
# Eval--Epoch: 14, Step: 1058/10593, L_p cnt: 7372, L_neg cnt: 2524	GT DDI Rate: 0.0851, DDI Rate: 0.0610, Jaccard: 0.4176,  PRAUC: 0.6674, AVG_PRC: 0.6579, AVG_RECALL: 0.5417, AVG_F1: 0.5751
# avg med 10.963678516228748
# 	Epoch: 14, Loss: 0.1670, One Epoch Time: 1.74m, Appro Left Time: 0.72h
#
# Eval--Epoch: 15, Step: 1058/10593, L_p cnt: 7678, L_neg cnt: 2218	GT DDI Rate: 0.0851, DDI Rate: 0.0665, Jaccard: 0.4188,  PRAUC: 0.6682, AVG_PRC: 0.6581, AVG_RECALL: 0.5435, AVG_F1: 0.5764
# avg med 11.010046367851622
# 	Epoch: 15, Loss: 0.1731, One Epoch Time: 1.73m, Appro Left Time: 0.69h
#
# Eval--Epoch: 16, Step: 1058/10593, L_p cnt: 7887, L_neg cnt: 2009	GT DDI Rate: 0.0851, DDI Rate: 0.0659, Jaccard: 0.4182,  PRAUC: 0.6695, AVG_PRC: 0.6594, AVG_RECALL: 0.5413, AVG_F1: 0.5757
# avg med 10.947449768160741
# 	Epoch: 16, Loss: 0.1779, One Epoch Time: 1.76m, Appro Left Time: 0.68h
#
# Eval--Epoch: 17, Step: 1058/10593, L_p cnt: 8105, L_neg cnt: 1791	GT DDI Rate: 0.0851, DDI Rate: 0.0719, Jaccard: 0.4195,  PRAUC: 0.6700, AVG_PRC: 0.6593, AVG_RECALL: 0.5433, AVG_F1: 0.5771
# avg med 10.99806800618238
# 	Epoch: 17, Loss: 0.1822, One Epoch Time: 1.82m, Appro Left Time: 0.67h
#
# Eval--Epoch: 18, Step: 1058/10593, L_p cnt: 8388, L_neg cnt: 1508	GT DDI Rate: 0.0851, DDI Rate: 0.0724, Jaccard: 0.4226,  PRAUC: 0.6714, AVG_PRC: 0.6547, AVG_RECALL: 0.5526, AVG_F1: 0.5802
# avg med 11.273570324574962
# 	Epoch: 18, Loss: 0.1880, One Epoch Time: 1.83m, Appro Left Time: 0.64h
#
# Eval--Epoch: 19, Step: 1058/10593, L_p cnt: 8560, L_neg cnt: 1336	GT DDI Rate: 0.0851, DDI Rate: 0.0735, Jaccard: 0.4224,  PRAUC: 0.6723, AVG_PRC: 0.6559, AVG_RECALL: 0.5508, AVG_F1: 0.5799
# avg med 11.226043276661514
# 	Epoch: 19, Loss: 0.1917, One Epoch Time: 1.79m, Appro Left Time: 0.60h
#
# Eval--Epoch: 20, Step: 1058/10593, L_p cnt: 8779, L_neg cnt: 1117	GT DDI Rate: 0.0851, DDI Rate: 0.0771, Jaccard: 0.4240,  PRAUC: 0.6724, AVG_PRC: 0.6572, AVG_RECALL: 0.5524, AVG_F1: 0.5815
# avg med 11.24420401854714
# 	Epoch: 20, Loss: 0.1960, One Epoch Time: 1.85m, Appro Left Time: 0.59h
#
# Eval--Epoch: 21, Step: 1058/10593, L_p cnt: 8954, L_neg cnt: 942	GT DDI Rate: 0.0851, DDI Rate: 0.0759, Jaccard: 0.4236,  PRAUC: 0.6735, AVG_PRC: 0.6591, AVG_RECALL: 0.5501, AVG_F1: 0.5808
# avg med 11.169242658423492
# 	Epoch: 21, Loss: 0.1998, One Epoch Time: 1.73m, Appro Left Time: 0.52h
#
# Eval--Epoch: 22, Step: 1058/10593, L_p cnt: 9030, L_neg cnt: 866	GT DDI Rate: 0.0851, DDI Rate: 0.0771, Jaccard: 0.4255,  PRAUC: 0.6734, AVG_PRC: 0.6510, AVG_RECALL: 0.5593, AVG_F1: 0.5827
# avg med 11.511978361669243
# 	Epoch: 22, Loss: 0.2011, One Epoch Time: 1.66m, Appro Left Time: 0.47h
#
# Eval--Epoch: 23, Step: 1058/10593, L_p cnt: 9174, L_neg cnt: 722	GT DDI Rate: 0.0851, DDI Rate: 0.0763, Jaccard: 0.4272,  PRAUC: 0.6744, AVG_PRC: 0.6517, AVG_RECALL: 0.5610, AVG_F1: 0.5844
# avg med 11.549072642967543
# 	Epoch: 23, Loss: 0.2037, One Epoch Time: 1.67m, Appro Left Time: 0.45h
#
# Eval--Epoch: 24, Step: 1058/10593, L_p cnt: 9201, L_neg cnt: 695	GT DDI Rate: 0.0851, DDI Rate: 0.0788, Jaccard: 0.4271,  PRAUC: 0.6752, AVG_PRC: 0.6550, AVG_RECALL: 0.5588, AVG_F1: 0.5842
# avg med 11.444358578052551
# 	Epoch: 24, Loss: 0.2038, One Epoch Time: 1.66m, Appro Left Time: 0.41h
#
# Eval--Epoch: 25, Step: 1058/10593, L_p cnt: 9244, L_neg cnt: 652	GT DDI Rate: 0.0851, DDI Rate: 0.0830, Jaccard: 0.4262,  PRAUC: 0.6754, AVG_PRC: 0.6551, AVG_RECALL: 0.5568, AVG_F1: 0.5832
# avg med 11.432380216383308
# 	Epoch: 25, Loss: 0.2046, One Epoch Time: 1.78m, Appro Left Time: 0.42h
#
# Eval--Epoch: 26, Step: 1058/10593, L_p cnt: 9348, L_neg cnt: 548	GT DDI Rate: 0.0851, DDI Rate: 0.0788, Jaccard: 0.4287,  PRAUC: 0.6762, AVG_PRC: 0.6521, AVG_RECALL: 0.5629, AVG_F1: 0.5857
# avg med 11.598918083462133
# 	Epoch: 26, Loss: 0.2065, One Epoch Time: 1.87m, Appro Left Time: 0.41h
#
# Eval--Epoch: 27, Step: 1058/10593, L_p cnt: 9372, L_neg cnt: 524	GT DDI Rate: 0.0851, DDI Rate: 0.0787, Jaccard: 0.4282,  PRAUC: 0.6769, AVG_PRC: 0.6574, AVG_RECALL: 0.5585, AVG_F1: 0.5850
# avg med 11.4258114374034
# 	Epoch: 27, Loss: 0.2064, One Epoch Time: 1.90m, Appro Left Time: 0.38h
#
# Eval--Epoch: 28, Step: 1058/10593, L_p cnt: 9425, L_neg cnt: 471	GT DDI Rate: 0.0851, DDI Rate: 0.0797, Jaccard: 0.4301,  PRAUC: 0.6771, AVG_PRC: 0.6514, AVG_RECALL: 0.5662, AVG_F1: 0.5870
# avg med 11.652627511591962
# 	Epoch: 28, Loss: 0.2070, One Epoch Time: 1.70m, Appro Left Time: 0.31h
#
# Eval--Epoch: 29, Step: 1058/10593, L_p cnt: 9468, L_neg cnt: 428	GT DDI Rate: 0.0851, DDI Rate: 0.0826, Jaccard: 0.4302,  PRAUC: 0.6767, AVG_PRC: 0.6533, AVG_RECALL: 0.5652, AVG_F1: 0.5871
# avg med 11.639103554868624
# 	Epoch: 29, Loss: 0.2076, One Epoch Time: 1.67m, Appro Left Time: 0.28h
#
# Eval--Epoch: 30, Step: 1058/10593, L_p cnt: 9539, L_neg cnt: 357	GT DDI Rate: 0.0851, DDI Rate: 0.0872, Jaccard: 0.4325,  PRAUC: 0.6764, AVG_PRC: 0.6472, AVG_RECALL: 0.5722, AVG_F1: 0.5892
# avg med 11.906105100463678
# 	Epoch: 30, Loss: 0.2089, One Epoch Time: 1.84m, Appro Left Time: 0.28h
#
# Eval--Epoch: 31, Step: 1058/10593, L_p cnt: 9598, L_neg cnt: 298	GT DDI Rate: 0.0851, DDI Rate: 0.0839, Jaccard: 0.4323,  PRAUC: 0.6769, AVG_PRC: 0.6474, AVG_RECALL: 0.5720, AVG_F1: 0.5892
# avg med 11.877511591962906
# 	Epoch: 31, Loss: 0.2095, One Epoch Time: 1.68m, Appro Left Time: 0.22h
#
# Eval--Epoch: 32, Step: 1058/10593, L_p cnt: 9641, L_neg cnt: 255	GT DDI Rate: 0.0851, DDI Rate: 0.0800, Jaccard: 0.4302,  PRAUC: 0.6783, AVG_PRC: 0.6526, AVG_RECALL: 0.5654, AVG_F1: 0.5869
# avg med 11.640262751159197
# 	Epoch: 32, Loss: 0.2105, One Epoch Time: 1.68m, Appro Left Time: 0.20h
#
# Eval--Epoch: 33, Step: 1058/10593, L_p cnt: 9667, L_neg cnt: 229	GT DDI Rate: 0.0851, DDI Rate: 0.0826, Jaccard: 0.4328,  PRAUC: 0.6774, AVG_PRC: 0.6509, AVG_RECALL: 0.5703, AVG_F1: 0.5893
# avg med 11.769319938176197
# 	Epoch: 33, Loss: 0.2103, One Epoch Time: 1.68m, Appro Left Time: 0.17h
#
# Eval--Epoch: 34, Step: 1058/10593, L_p cnt: 9703, L_neg cnt: 193	GT DDI Rate: 0.0851, DDI Rate: 0.0817, Jaccard: 0.4316,  PRAUC: 0.6780, AVG_PRC: 0.6497, AVG_RECALL: 0.5694, AVG_F1: 0.5883
# avg med 11.788253477588873
# 	Epoch: 34, Loss: 0.2108, One Epoch Time: 1.83m, Appro Left Time: 0.15h
#
# Eval--Epoch: 35, Step: 1058/10593, L_p cnt: 9739, L_neg cnt: 157	GT DDI Rate: 0.0851, DDI Rate: 0.0831, Jaccard: 0.4323,  PRAUC: 0.6785, AVG_PRC: 0.6509, AVG_RECALL: 0.5699, AVG_F1: 0.5893
# avg med 11.785548686244203
# 	Epoch: 35, Loss: 0.2112, One Epoch Time: 1.84m, Appro Left Time: 0.12h
#
# Eval--Epoch: 36, Step: 1058/10593, L_p cnt: 9770, L_neg cnt: 126	GT DDI Rate: 0.0851, DDI Rate: 0.0807, Jaccard: 0.4321,  PRAUC: 0.6788, AVG_PRC: 0.6508, AVG_RECALL: 0.5696, AVG_F1: 0.5890
# avg med 11.788639876352395
# 	Epoch: 36, Loss: 0.2114, One Epoch Time: 1.80m, Appro Left Time: 0.09h
#
# Eval--Epoch: 37, Step: 1058/10593, L_p cnt: 9803, L_neg cnt: 93	GT DDI Rate: 0.0851, DDI Rate: 0.0820, Jaccard: 0.4312,  PRAUC: 0.6783, AVG_PRC: 0.6457, AVG_RECALL: 0.5718, AVG_F1: 0.5877
# avg med 11.976816074188562
# 	Epoch: 37, Loss: 0.2118, One Epoch Time: 1.94m, Appro Left Time: 0.06h
#
# Eval--Epoch: 38, Step: 1058/10593, L_p cnt: 9835, L_neg cnt: 61	GT DDI Rate: 0.0851, DDI Rate: 0.0806, Jaccard: 0.4315,  PRAUC: 0.6783, AVG_PRC: 0.6521, AVG_RECALL: 0.5673, AVG_F1: 0.5880
# avg med 11.747295208655332
# 	Epoch: 38, Loss: 0.2122, One Epoch Time: 1.95m, Appro Left Time: 0.03h
#
# Eval--Epoch: 39, Step: 1058/10593, L_p cnt: 9834, L_neg cnt: 62	GT DDI Rate: 0.0851, DDI Rate: 0.0844, Jaccard: 0.4319,  PRAUC: 0.6788, AVG_PRC: 0.6495, AVG_RECALL: 0.5706, AVG_F1: 0.5885
# avg med 11.865919629057187
# 	Epoch: 39, Loss: 0.2120, One Epoch Time: 1.93m, Appro Left Time: 0.00h
#
# best_epoch: 33

# %%
# %run train_GAMENet.py --model_name GAMENet --ddi --resume_path Epoch_33_JA_0.4328_DDI_0.0826.model --eval
# Out:
# parameters 536534
# Eval--Epoch: 0, Step: 1057/1058	GT DDI Rate: 0.0868, DDI Rate: 0.0861, Jaccard: 0.4255,  PRAUC: 0.6709, AVG_PRC: 0.6451, AVG_RECALL: 0.5643, AVG_F1: 0.5826
# avg med 11.66785150078989

# %%
# %run train_GAMENet.py --model_name GAMENet
# Out:
# parameters 536534
# Eval--Epoch: 0, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0644, Jaccard: 0.3464,  PRAUC: 0.6053, AVG_PRC: 0.6527, AVG_RECALL: 0.4402, AVG_F1: 0.5054
# avg med 9.093508500772797
# 	Epoch: 0, Loss: 0.2581, One Epoch Time: 1.63m, Appro Left Time: 1.06h
#
# Eval--Epoch: 1, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0507, Jaccard: 0.3809,  PRAUC: 0.6263, AVG_PRC: 0.6445, AVG_RECALL: 0.4941, AVG_F1: 0.5389
# avg med 10.234157650695519
# 	Epoch: 1, Loss: 0.2508, One Epoch Time: 1.67m, Appro Left Time: 1.06h
#
# Eval--Epoch: 2, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0620, Jaccard: 0.3898,  PRAUC: 0.6378, AVG_PRC: 0.6517, AVG_RECALL: 0.5016, AVG_F1: 0.5476
# avg med 10.221792890262751
# 	Epoch: 2, Loss: 0.2418, One Epoch Time: 1.60m, Appro Left Time: 0.99h
#
# Eval--Epoch: 3, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0630, Jaccard: 0.3951,  PRAUC: 0.6471, AVG_PRC: 0.6608, AVG_RECALL: 0.5044, AVG_F1: 0.5527
# avg med 10.171561051004637
# 	Epoch: 3, Loss: 0.2367, One Epoch Time: 1.66m, Appro Left Time: 1.00h
#
# Eval--Epoch: 4, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0638, Jaccard: 0.4011,  PRAUC: 0.6516, AVG_PRC: 0.6558, AVG_RECALL: 0.5181, AVG_F1: 0.5584
# avg med 10.530911901081916
# 	Epoch: 4, Loss: 0.2337, One Epoch Time: 1.68m, Appro Left Time: 0.98h
#
# Eval--Epoch: 5, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0673, Jaccard: 0.4077,  PRAUC: 0.6568, AVG_PRC: 0.6554, AVG_RECALL: 0.5286, AVG_F1: 0.5653
# avg med 10.792117465224111
# 	Epoch: 5, Loss: 0.2313, One Epoch Time: 1.54m, Appro Left Time: 0.87h
#
# Eval--Epoch: 6, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0664, Jaccard: 0.4116,  PRAUC: 0.6612, AVG_PRC: 0.6528, AVG_RECALL: 0.5359, AVG_F1: 0.5691
# avg med 10.991885625965997
# 	Epoch: 6, Loss: 0.2294, One Epoch Time: 1.56m, Appro Left Time: 0.86h
#
# Eval--Epoch: 7, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0683, Jaccard: 0.4151,  PRAUC: 0.6641, AVG_PRC: 0.6540, AVG_RECALL: 0.5408, AVG_F1: 0.5725
# avg med 11.068006182380216
# 	Epoch: 7, Loss: 0.2274, One Epoch Time: 1.68m, Appro Left Time: 0.90h
#
# Eval--Epoch: 8, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0701, Jaccard: 0.4181,  PRAUC: 0.6669, AVG_PRC: 0.6538, AVG_RECALL: 0.5453, AVG_F1: 0.5753
# avg med 11.213292117465224
# 	Epoch: 8, Loss: 0.2261, One Epoch Time: 1.65m, Appro Left Time: 0.85h
#
# Eval--Epoch: 9, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0714, Jaccard: 0.4196,  PRAUC: 0.6689, AVG_PRC: 0.6517, AVG_RECALL: 0.5496, AVG_F1: 0.5771
# avg med 11.3241885625966
# 	Epoch: 9, Loss: 0.2248, One Epoch Time: 1.51m, Appro Left Time: 0.75h
#
# Eval--Epoch: 10, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0736, Jaccard: 0.4205,  PRAUC: 0.6702, AVG_PRC: 0.6553, AVG_RECALL: 0.5490, AVG_F1: 0.5780
# avg med 11.259273570324575
# 	Epoch: 10, Loss: 0.2237, One Epoch Time: 1.59m, Appro Left Time: 0.77h
#
# Eval--Epoch: 11, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0728, Jaccard: 0.4220,  PRAUC: 0.6718, AVG_PRC: 0.6575, AVG_RECALL: 0.5489, AVG_F1: 0.5793
# avg med 11.23918083462133
# 	Epoch: 11, Loss: 0.2226, One Epoch Time: 33.72m, Appro Left Time: 15.74h
#
# Eval--Epoch: 12, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0743, Jaccard: 0.4239,  PRAUC: 0.6722, AVG_PRC: 0.6534, AVG_RECALL: 0.5550, AVG_F1: 0.5814
# avg med 11.419242658423492
# 	Epoch: 12, Loss: 0.2217, One Epoch Time: 1.76m, Appro Left Time: 0.79h
#
# Eval--Epoch: 13, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0749, Jaccard: 0.4265,  PRAUC: 0.6730, AVG_PRC: 0.6545, AVG_RECALL: 0.5582, AVG_F1: 0.5838
# avg med 11.456336939721792
# 	Epoch: 13, Loss: 0.2208, One Epoch Time: 1.56m, Appro Left Time: 0.68h
#
# Eval--Epoch: 14, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0758, Jaccard: 0.4266,  PRAUC: 0.6734, AVG_PRC: 0.6582, AVG_RECALL: 0.5554, AVG_F1: 0.5839
# avg med 11.337712519319938
# 	Epoch: 14, Loss: 0.2199, One Epoch Time: 1.49m, Appro Left Time: 0.62h
#
# Eval--Epoch: 15, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0755, Jaccard: 0.4288,  PRAUC: 0.6752, AVG_PRC: 0.6519, AVG_RECALL: 0.5630, AVG_F1: 0.5859
# avg med 11.612055641421948
# 	Epoch: 15, Loss: 0.2192, One Epoch Time: 1.54m, Appro Left Time: 0.61h
#
# Eval--Epoch: 16, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0757, Jaccard: 0.4299,  PRAUC: 0.6758, AVG_PRC: 0.6554, AVG_RECALL: 0.5620, AVG_F1: 0.5869
# avg med 11.515842349304481
# 	Epoch: 16, Loss: 0.2185, One Epoch Time: 1.58m, Appro Left Time: 0.61h
#
# Eval--Epoch: 17, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0783, Jaccard: 0.4297,  PRAUC: 0.6759, AVG_PRC: 0.6525, AVG_RECALL: 0.5639, AVG_F1: 0.5868
# avg med 11.639489953632149
# 	Epoch: 17, Loss: 0.2178, One Epoch Time: 1.66m, Appro Left Time: 0.61h
#
# Eval--Epoch: 18, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0760, Jaccard: 0.4300,  PRAUC: 0.6769, AVG_PRC: 0.6559, AVG_RECALL: 0.5617, AVG_F1: 0.5869
# avg med 11.497681607418857
# 	Epoch: 18, Loss: 0.2171, One Epoch Time: 1.50m, Appro Left Time: 0.53h
#
# Eval--Epoch: 19, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0777, Jaccard: 0.4318,  PRAUC: 0.6776, AVG_PRC: 0.6552, AVG_RECALL: 0.5651, AVG_F1: 0.5887
# avg med 11.593122102009273
# 	Epoch: 19, Loss: 0.2166, One Epoch Time: 1.52m, Appro Left Time: 0.51h
#
# Eval--Epoch: 20, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0811, Jaccard: 0.4318,  PRAUC: 0.6781, AVG_PRC: 0.6538, AVG_RECALL: 0.5660, AVG_F1: 0.5888
# avg med 11.642967542503865
# 	Epoch: 20, Loss: 0.2161, One Epoch Time: 1.56m, Appro Left Time: 0.50h
#
# Eval--Epoch: 21, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0772, Jaccard: 0.4323,  PRAUC: 0.6788, AVG_PRC: 0.6550, AVG_RECALL: 0.5653, AVG_F1: 0.5890
# avg med 11.625193199381762
# 	Epoch: 21, Loss: 0.2154, One Epoch Time: 1.61m, Appro Left Time: 0.48h
#
# Eval--Epoch: 22, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0773, Jaccard: 0.4320,  PRAUC: 0.6796, AVG_PRC: 0.6528, AVG_RECALL: 0.5663, AVG_F1: 0.5885
# avg med 11.683153013910356
# 	Epoch: 22, Loss: 0.2150, One Epoch Time: 1.56m, Appro Left Time: 0.44h
#
# Eval--Epoch: 23, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0797, Jaccard: 0.4313,  PRAUC: 0.6796, AVG_PRC: 0.6531, AVG_RECALL: 0.5657, AVG_F1: 0.5882
# avg med 11.624806800618238
# 	Epoch: 23, Loss: 0.2145, One Epoch Time: 1.75m, Appro Left Time: 0.47h
#
# Eval--Epoch: 24, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0813, Jaccard: 0.4332,  PRAUC: 0.6798, AVG_PRC: 0.6478, AVG_RECALL: 0.5727, AVG_F1: 0.5899
# avg med 11.894126738794435
# 	Epoch: 24, Loss: 0.2140, One Epoch Time: 1.60m, Appro Left Time: 0.40h
#
# Eval--Epoch: 25, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0833, Jaccard: 0.4331,  PRAUC: 0.6800, AVG_PRC: 0.6548, AVG_RECALL: 0.5671, AVG_F1: 0.5896
# avg med 11.671174652241113
# 	Epoch: 25, Loss: 0.2137, One Epoch Time: 1.67m, Appro Left Time: 0.39h
#
# Eval--Epoch: 26, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0817, Jaccard: 0.4336,  PRAUC: 0.6805, AVG_PRC: 0.6469, AVG_RECALL: 0.5739, AVG_F1: 0.5901
# avg med 11.937017001545595
# 	Epoch: 26, Loss: 0.2132, One Epoch Time: 1.51m, Appro Left Time: 0.33h
#
# Eval--Epoch: 27, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0826, Jaccard: 0.4332,  PRAUC: 0.6804, AVG_PRC: 0.6537, AVG_RECALL: 0.5682, AVG_F1: 0.5897
# avg med 11.70710973724884
# 	Epoch: 27, Loss: 0.2129, One Epoch Time: 1.56m, Appro Left Time: 0.31h
#
# Eval--Epoch: 28, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0825, Jaccard: 0.4345,  PRAUC: 0.6804, AVG_PRC: 0.6482, AVG_RECALL: 0.5737, AVG_F1: 0.5908
# avg med 11.918083462132921
# 	Epoch: 28, Loss: 0.2124, One Epoch Time: 1.51m, Appro Left Time: 0.28h
# Eval--Epoch: 29, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0809, Jaccard: 0.4328,  PRAUC: 0.6810, AVG_PRC: 0.6496, AVG_RECALL: 0.5703, AVG_F1: 0.5892
# avg med 11.818778979907265
# 	Epoch: 29, Loss: 0.2119, One Epoch Time: 1.48m, Appro Left Time: 0.25h
#
# Eval--Epoch: 30, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0847, Jaccard: 0.4334,  PRAUC: 0.6805, AVG_PRC: 0.6496, AVG_RECALL: 0.5707, AVG_F1: 0.5898
# avg med 11.857032457496135
# 	Epoch: 30, Loss: 0.2117, One Epoch Time: 1.53m, Appro Left Time: 0.23h
#
# Eval--Epoch: 31, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0886, Jaccard: 0.4349,  PRAUC: 0.6792, AVG_PRC: 0.6467, AVG_RECALL: 0.5760, AVG_F1: 0.5914
# avg med 12.006568778979908
# 	Epoch: 31, Loss: 0.2112, One Epoch Time: 1.58m, Appro Left Time: 0.21h
#
# Eval--Epoch: 32, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0828, Jaccard: 0.4355,  PRAUC: 0.6812, AVG_PRC: 0.6485, AVG_RECALL: 0.5757, AVG_F1: 0.5918
# avg med 11.947449768160741
# 	Epoch: 32, Loss: 0.2109, One Epoch Time: 1.59m, Appro Left Time: 0.19h
#
# Eval--Epoch: 33, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0851, Jaccard: 0.4341,  PRAUC: 0.6809, AVG_PRC: 0.6459, AVG_RECALL: 0.5742, AVG_F1: 0.5901
# avg med 12.0096599690881
# 	Epoch: 33, Loss: 0.2106, One Epoch Time: 1.62m, Appro Left Time: 0.16h
#
# Eval--Epoch: 34, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0850, Jaccard: 0.4342,  PRAUC: 0.6807, AVG_PRC: 0.6500, AVG_RECALL: 0.5721, AVG_F1: 0.5902
# avg med 11.880602782071097
# 	Epoch: 34, Loss: 0.2103, One Epoch Time: 1.54m, Appro Left Time: 0.13h
#
# Eval--Epoch: 35, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0853, Jaccard: 0.4340,  PRAUC: 0.6815, AVG_PRC: 0.6476, AVG_RECALL: 0.5735, AVG_F1: 0.5901
# avg med 12.001159196290573
# 	Epoch: 35, Loss: 0.2101, One Epoch Time: 1.50m, Appro Left Time: 0.10h
#
# Eval--Epoch: 36, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0860, Jaccard: 0.4325,  PRAUC: 0.6807, AVG_PRC: 0.6463, AVG_RECALL: 0.5720, AVG_F1: 0.5889
# avg med 11.943585780525503
# 	Epoch: 36, Loss: 0.2097, One Epoch Time: 1.50m, Appro Left Time: 0.08h
#
# Eval--Epoch: 37, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0854, Jaccard: 0.4341,  PRAUC: 0.6805, AVG_PRC: 0.6466, AVG_RECALL: 0.5743, AVG_F1: 0.5901
# avg med 11.985703245749614
# 	Epoch: 37, Loss: 0.2093, One Epoch Time: 1.59m, Appro Left Time: 0.05h
#
# Eval--Epoch: 38, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0865, Jaccard: 0.4350,  PRAUC: 0.6810, AVG_PRC: 0.6455, AVG_RECALL: 0.5776, AVG_F1: 0.5913
# avg med 12.106646058732611
# 	Epoch: 38, Loss: 0.2092, One Epoch Time: 1.59m, Appro Left Time: 0.03h
#
# Eval--Epoch: 39, Step: 1058/10593, L_p cnt: 0, L_neg cnt: 0	GT DDI Rate: 0.0851, DDI Rate: 0.0871, Jaccard: 0.4347,  PRAUC: 0.6802, AVG_PRC: 0.6457, AVG_RECALL: 0.5761, AVG_F1: 0.5909
# avg med 12.041731066460587
# 	Epoch: 39, Loss: 0.2089, One Epoch Time: 1.63m, Appro Left Time: 0.00h
#
# best_epoch: 32

# %%
# %run train_GAMENet.py --model_name GAMENet --resume_path Epoch_32_JA_0.4355_DDI_0.0828.model --eval
# Out:
# parameters 536534
# Eval--Epoch: 0, Step: 1057/1058	GT DDI Rate: 0.0868, DDI Rate: 0.0844, Jaccard: 0.4294,  PRAUC: 0.6747, AVG_PRC: 0.6422, AVG_RECALL: 0.5711, AVG_F1: 0.5860
# avg med 11.873222748815166

# %% [markdown]
# ## Conclusion
# Our demo notebook showcases the essential steps involved in reproducing the research paper "GAMENet: Graph Augmented MEmory Networks for Recommending Medication Combination". The results and additional things we have tried are discussed in more detail in our final report. We hope that this demo will help others to understand the research process and inspire further research in this field.
